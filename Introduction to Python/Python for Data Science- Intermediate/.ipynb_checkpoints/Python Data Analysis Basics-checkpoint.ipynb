# %%
from csv import reader

# Read the `artworks_clean.csv` file
opened_file = open('artworks_clean.csv', encoding='utf-8')
read_file = reader(opened_file)
moma = list(read_file)
moma = moma[1:]

# %%
# Converted birthdate values
for row in moma:
    birth_date = row[3]
    if birth_date != "":
        birth_date = int(birth_date)
    row[3] = birth_date
    
# Converted death date values
for row in moma:
    death_date = row[4]
    if death_date != "":
        death_date = int(death_date)
    row[4] = death_date

# %%
for row in moma:
    date = row[6]
    if date != "":
        date = int(date)
    row[6] = date

# %%
ages = []

for row in moma:
    date = row[6]
    birth = row[3]
    if birth != "":
        age = date - birth
    if birth == "":
        age = 0
    ages.append(age)

# %%
final_ages = []

for age in ages:
    if age > 20:
        final_age = age
    if age <= 20:
        final_age = 'Unknown'
    final_ages.append(final_age)

# %%
decades = []

for age in final_ages:
    if age == 'Unknown':
        decade = age
    if age != 'Unknown':
        decade = str(age)
        decade = decade[:-1]
        decade = decade + '0s'
    decades.append(decade)

# %%
decade_frequency = {}

for item in decades:
    if item not in decade_frequency:
        decade_frequency[item] = 1
    else:
        decade_frequency[item] += 1

# %% [markdown]
# ## The .format method for string output

# %% [markdown]
# ### .format method demo

# %% [markdown]
# `artist = "Pablo Picasso"
# birth_year = 1881`
#
# #### basic format
# `output = "{} was born in {}.".format(artist, birth_year)
# print(output)`
#
# #### index format
# `output = "{0} was born in {1}. {1} is a year in the 1800s.".format(artist, birth_year)
# print(output)`
#
# #### keyword format
# `output = "{name} was born in {year}. {year} is a year in the 1800s.".format(name=artist, year=birth_year)
# print(output)`

# %% [markdown]
# This will create a frequency table of artists and the number of artworks in the dataset

# %%
artist_freq = {}

for row in moma:
    a = row[1]
    
    if a not in artist_freq:
        artist_freq[a] = 1
        
    else:
        artist_freq[a] += 1
        
print(artist_freq)
# Out:
# {'Sarah Charlesworth': 1, 'Pablo Palazuelo': 4, 'Maurice Denis': 71, 'Aristide Maillol': 77, 'Eugène Atget': 705, 'Antonio Frasconi': 41, 'Garry Winogrand': 47, 'Diane Victor': 4, 'David Brown Milne': 2, 'Jean Dubuffet': 206, 'Jim Dine': 57, 'František Kupka': 37, 'Franklin Chenault Watkins': 4, 'Christopher Wool': 19, 'Abraham Walkowitz': 19, 'Pierre Alechinsky': 67, 'Frank Stella': 17, 'Frank Lloyd Wright': 112, 'Vicente Rojo': 5, 'Ludwig Mies van der Rohe': 318, 'Varvara Stepanova': 6, 'Richard Serra': 4, 'Robert Filliou': 15, 'Roger Chancel': 3, 'Pierre Bonnard': 129, 'Jacqueline Poncelet': 1, 'Émile Bernard': 83, 'Georg Baselitz': 14, 'Frans Masereel': 34, 'Unknown': 448, 'Sol LeWitt': 89, 'James Tenney': 1, 'Claes Oldenburg': 12, 'Dieter Roth': 18, 'Moisei Fradkin': 1, 'Richard Lindner': 1, 'Wojciech Prazmowski': 2, 'Thomas Bewick': 49, 'Spencer Sweeney': 2, 'Batiste Madalena': 5, 'On Kawara': 9, 'Andy Warhol': 41, 'Lee Friedlander': 180, 'Joan Miró': 78, 'Marc Chagall': 173, 'Robert Rauschenberg': 45, 'Dennis Oppenheim': 7, 'Richard Nonas': 4, 'Adrian Piper': 14, 'George Maciunas': 72, 'Louise Bourgeois': 495, 'Álvaro Siza': 23, 'Ellen Phelan': 2, 'Josef Hoffmann': 9, 'Mario Botta': 4, 'Thomas Schütte': 33, 'Henry Hamilton Bennett': 3, 'Pavel Tchelitchew': 26, 'Fiona Banner': 10, 'Felix Gonzalez-Torres': 6, 'Léo Marchutz': 14, 'Aaron Siskind': 19, 'Helmut A. P. Grieshaber': 4, 'Georges Rouault': 68, 'Fred Williams': 2, 'Paul Strand': 23, 'Marie Laurencin': 10, 'Juan Hidalgo': 7, 'Michael Schmidt': 38, 'Kiki Smith': 21, 'Stephen Shore': 23, 'Henri de Toulouse-Lautrec': 19, 'Willem de Kooning': 29, 'Stephen White': 7, 'Robert Heinecken': 8, 'Studio Opi': 1, 'Frederick Kiesler': 5, 'Ezra Stoller': 1, 'Emily Hubley': 2, 'Benjamin Patterson': 16, 'James Montgomery Flagg': 1, 'Carey Maxon': 1, 'Jorge Pardo': 9, 'Cesare Peverelli': 4, 'Alexander Henderson': 3, 'Ross McElwee': 1, 'Sandra Vásquez de la Horra': 1, 'Barnett Newman': 7, 'Eadweard J. Muybridge': 38, 'Robert Frank': 30, 'Fernand Léger': 30, 'Bradford Washburn': 3, 'Man Ray (Emmanuel Radnitzky)': 24, 'Gerald Jackson': 10, 'John Sloan': 20, 'Miguel Angel Rojas': 1, 'Stephen Scheer': 2, 'Roman Signer': 29, 'Lilly Reich': 118, 'Sidney Nolan': 9, 'George Overbury ("Pop") Hart': 26, 'Antoni Tàpies': 27, 'José Chávez Morado': 4, 'Herbert Bayer': 20, 'Slavs and Tatars': 1, 'André Dunoyer de Segonzac': 38, 'Nicholas Nixon': 25, 'William Scott': 1, 'Candido Portinari': 3, 'Ernst Ludwig Kirchner': 17, 'David Wark Griffith': 4, 'Jan Dibbets': 66, 'Wladyslaw Strzemiński': 3, 'Winfred Gaul': 1, 'Mircea Cantor': 1, 'Augustin Tschinkel': 4, 'Elaine Lustig Cohen': 33, 'Judith Joy Ross': 16, 'Jules Pascin': 40, 'Paul Thek': 2, 'Larry Rivers': 28, 'Christian Fossier': 2, 'Michel Guino': 2, 'Arthur B. Davies': 8, 'Lauretta Vinciarelli': 19, 'Gertrude Käsebier': 11, 'Jean (Hans) Arp': 36, 'Jean Charlot': 18, 'Thomas Roma': 14, 'Stephen Shames': 1, 'Pat Keely': 4, 'André Masson': 49, 'Robert Watts': 30, 'J. Briones': 1, 'Max Weber': 22, 'Bruce Conner': 16, 'Sam Francis': 5, 'Mateo Manaure': 4, 'Haegue Yang': 4, 'André Derain': 86, 'Walter Richard Sickert': 7, 'Moshe Gershuni': 2, 'William Henry Jackson': 10, 'George Brecht': 19, 'Kelley Walker': 14, 'Lisa Yuskavage': 2, 'William R. Current': 1, 'Philip Fein': 1, 'Seong Moy': 2, 'Paul Rand': 2, 'Dorothea Lange': 83, 'Alex Israel': 1, 'El Lissitzky': 18, 'Jasper Johns': 76, 'Peter Blume': 1, 'Terry Winters': 21, 'César Paternosto': 1, 'Joe Goode': 5, 'Larry Bell': 1, 'Richard Artschwager': 13, 'Dan McCarthy': 1, 'Wade Guyton': 2, 'Raj Rewal': 11, 'Hella Fischer-Thorer': 1, 'Zinovii Gorbovets': 1, 'Peter Doig': 5, 'Juan Luis Martinez': 2, 'Amedeo Modigliani': 5, 'Juan Uslé': 3, 'Lynn Hershman Leeson': 5, 'Karl Gerstner': 3, 'Nathan Lyons': 2, 'Bob Cato': 1, 'Antonio Saura': 17, 'Renato Orara': 1, 'Tadanori Yokoo': 10, 'Jamie Reid': 1, 'Wolfgang Laib': 2, 'James Ensor': 8, 'Alfred Capel Cure': 18, 'Anni Albers': 25, 'Mimmo Paladino': 5, 'John ...

# %% [markdown]
# This will create a function that summarizes an artist's work by giving \n
# how many artworks the artist has created within the dataset.

# %%
def artist_summary(artist):
    num_artworks = artist_freq[artist]
    template = "There are {num} artworks by {name} in the dataset"
    output = template.format(name=artist, num=num_artworks)
    print(output)

artist_summary("Henri Matisse")
# Out:
# There are 129 artworks by Henri Matisse in the dataset

# %% [markdown]
# ### Other .format() method uses:

# %%
pop_millions = [
    ["China", 1379.302771],
    ["India", 1281.935991],
    ["USA",  326.625791],
    ["Indonesia",  260.580739],
    ["Brazil",  207.353391],
]
print(pop_millions[0][0])
# Out:
# China

# %%
print("{} has a population of {} million people.".format(pop_millions[0][0], pop_millions[0][1]))

#To format this statement with two decimals use the following syntax:
print("{} has a population of {pop:.2f} million people.".format(pop_millions[0][0], pop=pop_millions[0][1]))
# Out:
# China has a population of 1379.302771 million people.
# China has a population of 1379.30 million people.

# %%
India = 1281935991

print('India has a population of {}'.format(India))

# To format a large number with comma as a thousands separator, use the following syntax:
print('India has a population of {0:,}'.format(India))
# Out:
# India has a population of 1281935991
# India has a population of 1,281,935,991

# %%
for c in pop_millions:
    country = c[0]
    pop = c[1]
    template = "The population of {} is {:,.2f} million"
    print(template.format(country, pop))
# Out:
# The population of China is 1,379.30 million
# The population of India is 1,281.94 million
# The population of USA is 326.63 million
# The population of Indonesia is 260.58 million
# The population of Brazil is 207.35 million

# %% [markdown]
# ### The dict.items() method

# %%
fruit_freq = {'orange': 4,
              'banana': 4,
              'apple': 2}

for fruit, qty in fruit_freq.items():
    output = "I have {q} {f}s".format(f=fruit, q=qty)
    print(output)
# Out:
# I have 4 oranges
# I have 4 bananas
# I have 2 apples

# %% [markdown]
# # Working with the artworks dataset again

# %% [markdown]
# ### Creating a gender frequency table

# %%
gender_freq = {}

for g in moma[1:]:
    gender = g[5]
    if gender not in gender_freq:
        if gender != "":
            gender_freq[gender] = 0
    if gender in gender_freq:
        gender_freq[gender] += 1

# %% [markdown]
# ### Printing a string to display the number of artworks creating by each gender

# %%
for gender, artworks in gender_freq.items():
    output = "There are {a:,} artworks by {g} artists".format(g=gender, a=artworks)
    print(output)
# Out:
# There are 13,491 artworks by Male artists
# There are 2,442 artworks by Female artists
# There are 791 artworks by Gender Unknown/Other artists
