# %%
import pandas as pd
pd.read_csv("AppleStore.csv")
# Out:
#               id                                    track_name  size_bytes  \
# 0      284882215                                      Facebook   389879808
# 1      389801252                                     Instagram   113954816
# 2      529479190                                Clash of Clans   116476928
# 3      420009108                                    Temple Run    65921024
# 4      284035177                       Pandora - Music & Radio   130242560
# ...          ...                                           ...         ...
# 7192  1170406182  Shark Boom - Challenge Friends with your Pet   245415936
# 7193  1069830936                           【謎解き】ヤミすぎ彼女からのメッセージ    16808960
# 7194  1070052833                                    Go!Go!Cat!    91468800
# 7195  1081295232   Suppin Detective: Expose their true visage!    83026944
# 7196   977965019           みんなのお弁当 by クックパッド ~お弁当をレシピ付きで記録・共有~    51174400
#
#      currency  price  rating_count_tot  rating_count_ver  user_rating  \
# 0         USD    0.0           2974676               212          3.5
# 1         USD    0.0           2161558              1289          4.5
# 2         USD    0.0           2130805               579          4.5
# 3         USD    0.0           1724546              3842          4.5
# 4         USD    0.0           1126879              3594          4.0
# ...       ...    ...               ...               ...          ...
# 7192      USD    0.0                 0                 0          0.0
# 7193      USD    0.0                 0                 0          0.0
# 7194      USD    0.0                 0                 0          0.0
# 7195      USD    0.0                 0                 0          0.0
# 7196      USD    0.0                 0                 0          0.0
#
#       user_rating_ver      ver cont_rating        prime_genre  \
# 0                 3.5     95.0          4+  Social Networking
# 1                 4.0    10.23         12+      Photo & Video
# 2                 4.5  9.24.12          9+              Games
# 3                 4.0    1.6.2          9+              Games
# 4                 4.5    8.4.1         12+              Music
# ...               ...      ...         ...                ...
# 7192              0.0    1.0.9          4+              Games
# 7193              0.0      1.2          9+               Book
# 7194              0.0    1.1.2         12+              Games
# 7195              0.0    1.0.3         12+      Entertainment
# 7196              0.0    1.4.0          4+       Food & Drink
#
#       sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic
# 0                  37                1        29        1
# 1                  37                0        29        1
# 2                  38                5        18        1
# 3                  40                5         1        1
# 4                  37                4         1        1
# ...               ...              ...       ...      ...
# 7192               38                5         1        1
# 7193               38                0         1        1
# 7194               37                2         2        1
# 7195               40                0         1        1
# 7196               37                0         1        1
#
# [7197 rows x 16 columns]

# %%
app_names = ['Facebook', 'Instagram', 'Clash of Clans', 'Fruit Ninja Classic', 'Minecraft: Pocket Edition']

# %%
for element in app_names:
    print(element)
# Out:
# Facebook
# Instagram
# Clash of Clans
# Fruit Ninja Classic
# Minecraft: Pocket Edition

# %%
row_1 = ['Facebook', 0.0, 'USD', 2974676, 3.5]
row_2 = ['Instagram', 0.0, 'USD', 2161558, 4.5]
row_3 = ['Clash of Clans', 0.0, 'USD', 2130805, 4.5]
row_4 = ['Fruit Ninja Classic', 1.99, 'USD', 698516, 4.5]
row_5 = ['Minecraft: Pocket Edition', 6.99, 'USD', 522012, 4.5]

app_data_set = [row_1, row_2, row_3, row_4, row_5]

# %%
for row in app_data_set:
    rating_count = row[3]
    print(rating_count)
# Out:
# 2974676
# 2161558
# 2130805
# 698516
# 522012

# %%
for row in app_data_set:
    print(row)
# Out:
# ['Facebook', 0.0, 'USD', 2974676, 3.5]
# ['Instagram', 0.0, 'USD', 2161558, 4.5]
# ['Clash of Clans', 0.0, 'USD', 2130805, 4.5]
# ['Fruit Ninja Classic', 1.99, 'USD', 698516, 4.5]
# ['Minecraft: Pocket Edition', 6.99, 'USD', 522012, 4.5]

# %%
rating_sum = 0

for row in app_data_set:
    rating_count = row[3]
    rating_sum = rating_count + rating_sum
    print(rating_sum)
# Out:
# 2974676
# 5136234
# 7267039
# 7965555
# 8487567

# %%
rating_sum = 0

for row in app_data_set:
    rating = row[-1]
    rating_sum = rating + rating_sum
    print(rating_sum)

avg_rating = rating_sum / 5
# Out:
# 3.5
# 8.0
# 12.5
# 17.0
# 21.5

# %% [markdown]
# ### Working with files

# %%
from csv import reader

# %%
opened_file = open('AppleStore.csv')

# %%
read_file = reader(opened_file)

# %%
apps_data = list(read_file)

# %%
len(apps_data)
# Out:
# 7198

# %%
print(apps_data[0])
# Out:
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']

# %%
print(apps_data[1:3])
# Out:
# [['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1'], ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']]

# %%
header = apps_data[0]
apps_data = apps_data[1:]

# %%
rating_sum = 0

for row in apps_data:
    rating = float(row[7])
    rating_sum = rating + rating_sum

print(rating_sum)
print(len(apps_data))

avg_rating = round(rating_sum) / len(apps_data)
print(avg_rating)
# Out:
# 25383.5
# 7197
# 3.527025149367792

# %%
rating_sum = []

for row in apps_data[1:]:
    rating = float(row[7])
    rating_sum.append(rating)

print(rating_sum)

avg_rating = sum(rating_sum) / len(rating_sum)
print(avg_rating)
# Out:
# [4.5, 4.5, 4.5, 4.0, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 3.0, 4.5, 4.5, 3.5, 5.0, 3.5, 4.5, 4.5, 3.5, 5.0, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.0, 4.5, 4.5, 4.5, 4.5, 5.0, 4.5, 4.0, 3.5, 5.0, 4.5, 4.5, 3.5, 3.0, 4.5, 4.5, 4.0, 4.5, 5.0, 2.5, 3.5, 4.5, 4.5, 4.5, 4.5, 4.0, 4.0, 3.5, 4.5, 4.5, 2.5, 4.5, 4.0, 4.5, 4.5, 5.0, 4.0, 4.0, 5.0, 3.0, 5.0, 4.5, 3.5, 4.5, 4.5, 4.5, 4.5, 4.0, 4.5, 4.0, 4.0, 4.5, 4.5, 3.5, 4.0, 4.0, 4.5, 4.5, 4.5, 3.5, 3.5, 4.5, 4.5, 4.5, 4.0, 2.0, 3.5, 5.0, 4.5, 4.5, 4.5, 4.0, 4.5, 3.5, 4.5, 4.5, 4.5, 4.5, 4.5, 3.0, 4.5, 4.0, 3.5, 4.5, 4.5, 4.5, 5.0, 4.5, 4.0, 4.5, 4.0, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 3.5, 5.0, 4.5, 3.5, 4.5, 5.0, 4.5, 4.5, 4.5, 4.0, 4.5, 3.5, 4.0, 4.0, 5.0, 4.5, 4.0, 4.5, 4.5, 4.5, 4.5, 5.0, 4.5, 4.5, 3.5, 4.5, 4.5, 4.5, 5.0, 4.5, 3.5, 3.0, 4.5, 4.5, 4.5, 4.5, 3.5, 4.0, 4.5, 3.0, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.0, 3.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 3.5, 4.0, 3.0, 4.5, 3.0, 4.0, 3.5, 4.5, 3.5, 4.5, 4.5, 4.5, 3.5, 4.5, 4.5, 4.5, 4.5, 4.5, 5.0, 5.0, 4.0, 4.5, 4.0, 4.5, 4.5, 4.5, 4.5, 3.0, 3.5, 4.5, 4.5, 4.5, 4.0, 4.5, 4.0, 4.5, 5.0, 4.0, 5.0, 3.5, 4.5, 4.5, 5.0, 4.0, 2.5, 4.5, 4.5, 4.5, 4.5, 4.5, 5.0, 4.5, 4.0, 4.5, 4.5, 3.5, 4.5, 4.0, 4.5, 5.0, 4.5, 4.5, 5.0, 4.5, 3.0, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.0, 4.0, 4.5, 4.0, 4.5, 4.5, 3.5, 4.5, 4.5, 3.0, 4.5, 4.5, 4.5, 4.5, 4.0, 4.5, 4.5, 4.5, 4.5, 4.5, 4.0, 4.5, 4.5, 3.5, 4.0, 4.5, 4.5, 4.0, 4.5, 4.5, 4.5, 3.5, 3.0, 4.5, 4.0, 4.5, 5.0, 4.5, 3.0, 4.0, 3.0, 4.5, 4.5, 4.5, 4.5, 5.0, 5.0, 4.5, 3.0, 4.5, 4.5, 4.0, 4.0, 2.0, 4.5, 4.5, 4.0, 4.5, 3.5, 4.0, 4.5, 3.5, 4.5, 4.5, 2.5, 4.5, 4.5, 3.5, 4.5, 4.0, 4.5, 5.0, 3.5, 4.0, 4.5, 3.5, 4.5, 4.5, 4.5, 4.5, 3.5, 4.0, 4.5, 3.5, 4.5, 4.5, 4.5, 3.5, 3.5, 3.0, 4.5, 4.5, 3.5, 4.5, 3.0, 4.5, 4.5, 4.0, 4.5, 4.5, 4.5, 3.5, 4.0, 2.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 5.0, 4.5, 4.5, 4.5, 4.0, 5.0, 4.5, 4.5, 4.5, 4.5, 4.5, 3.5, 4.0, 4.5, 3.0, 4.5, 3.0, 4.5, 4.5, 4.5, 4.0, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.0, 4.5, 4.5, 4.0, 4.5, 4.0, 3.0, 3.5, 4.0, 4.5, 4.0, 4.5, 4.5, 2.5, 4.5, 4.5, 4.0, 4.5, 2.5, 4.5, 4.5, 4.5, 4.5, 4.0, 4.5, 4.0, 4.5, 4.5, 4.5, 5.0, 4.5, 4.0, 5.0, 4.5, 4.0, 3.5, 4.5, 4.5, 4.0, 4.5, 4.5, 4.5, 5.0, 4.5, 4.5, 4.0, 4.5, 4.5, 4.5, 4.5, 4.5, 4.0, 4.5, 4.5, 4.5, 3.5, 4.5, 4.5, 4.5, 4.5, 3.5, 4.5, 4.5, 4.5, 4.0, 4.5, 4.5, 4.0, 4.5, 4.5, 4.0, 3.5, 3.5, 3.5, 3.5, 5.0, 4.0, 4.5, 4.5, 4.5, 4.0, 4.5, 4.0, 4.5, 5.0, 4.5, 4.5, 4.5, 4.0, 4.5, 4.5, 4.5, 4.5, 4.0, 4.5, 4.5, 4.5, 5.0, 4.5, 3.0, 4.5, 4.5, 4.5, 4.5, 4.5, 4.0, 4.0, 4.5, 3.5, 4.5, 4.5, 4.5, 3.0, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.0, 4.5, 4.5, 4.5, 4.5, 5.0, 5.0, 4.5, 4.5, 4.5, 4.0, 4.5, 4.5, 4.0, 4.5, 4.5, 5.0, 4.5, 4.0, 4.5, 4.0, 4.5, 4.5, 4.5, 2.5, 4.5, 4.5, 4.5, 3.5, 4.0, 4.5, 4.5, 4.0, 3.5, 4.0, 3.5, 4.5, 4.5, 3.0, 4.5, 4.0, 5.0, 4.5, 5.0, 4.5, 4.5, 4.5, 4.5, 5.0, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 3.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.0, 4.0, 4.5, 4.5, 4.5, 4.5, 4.5, 3.0, 4.0, 4.0, 4.5, 4.5, 4.0, 4.5, 4.5, 5.0, 3.5, 4.5, 4.5, 4.5, 4.5, 4.0, 4.5, 4.0, 4.5, 4.5, 2.5, 4.5, 5.0, 4.5, 4.5, 4.5, 4.5, 4.5, 5.0, 4.5, 4.0, 4.5, 4.5, 4.5, 4.5, 4.0, 3.5, 4.5, 4.0, 5.0, 4.5, 4.0, 5.0, 4.5, 4.5, 3.5, 3.0, 4.5, 4.5, 4.0, 3.5, 4.0, 4.5, 4.5, 4.5, 4.5, 4.5, 3.5, 4.5, 4.5, 4.0, 4.5, 3.5, 4.5, 4.5, 4.5, 4.0, 4.5, 4.0, 4.0, 4.0, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.0, 4.5, 4.0, 5.0, 4.5, 4.5, 5.0, 4.5, 4.5, 4.5, 4.5, 4.5, 4.0, 4.0, 4.5, 4.5, 4.5, 4.0, 4.0, 4.0, 4.5, 4.0, 4.5, 4.5, 4.5, 4.0, 4.0, 4.5, 4.0, 4.5, 4.0, 3.5, 3.5, 4.0, 4.0, 4.5, 4.5, 4.0, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 2.5, 4.0, 4.5, 4.5, 4.5, 5.0, 4.0, 4.5, 4.0, 4.0, 4.5, 4.5, 4.5, 4.5, 4.5, 3.5, 3.0, 4.5, 4.5, 4.0, 4.5, 4.0, 4.5, 4.5, 4.0, 4.5, 3.5, 5.0, 5.0, 4.5, 4.0, 5.0, 4.0, 4.5, 4.0, 4.0, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 5.0, 4.5, 4.5, 4.5, 3.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.0, 4.0, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 3.0, 4.5, 3.5, 4.5, 5.0, 5.0, 4.0, 4.5, 4.5, 4.5, 4.0, 4.5, 3.5, 4.5, 4.5, 4.0, 4.0, 4.5, 4.5, 4.5, 4.5, 4.5, ...
# 3.526959421901056

# %% [markdown]
# ### If, Else, Elif Statements

# %%
apps_names = []
for row in apps_data[1:]:
    name = row[1]
    apps_names.append(name)
    
print(apps_names[:5])
# Out:
# ['Instagram', 'Clash of Clans', 'Temple Run', 'Pandora - Music & Radio', 'Pinterest']

# %%
free_apps_ratings = []
for row in apps_data[1:]:
    rating = float(row[7])
    price = float(row[4])
    if price == 0.0:
        free_apps_ratings.append(rating)
        
avg_rating_free = sum(free_apps_ratings) / len(free_apps_ratings)

# %%
a_price = 1

print(a_price == 0)
print(a_price == 1)
# Out:
# False
# True

# %%
if False:
    print("2 + 2 == 5")
    print("lemons are sour")

if True:
    print("the sky is blue")
    print("5 >= 3")
    
if False:
    print("spheres have corners")
    print("7 / 5 == 2")
# Out:
# the sky is blue
# 5 >= 3

# %%
non_free_apps_ratings = []
for row in apps_data[1:]:
    rating = float(row[7])
    price = float(row[4])   
    if price != 0.0:
        non_free_apps_ratings.append(rating)
    
avg_rating_non_free = sum(non_free_apps_ratings) / len(non_free_apps_ratings)

# %%
non_games_ratings = []

for row in apps_data[1:]:
    rating = float(row[7])
    genre = row[11]

    if genre != 'Games':
        non_games_ratings.append(rating)

avg_rating_non_games = sum(non_games_ratings) / len(non_games_ratings)
print(avg_rating_non_games)
# Out:
# 3.343881223755249

# %% [markdown]
# ### Multiple Condition If, Else, Elif Statements

# %%
free_games_ratings = []
for row in apps_data[1:]:
    rating = float(row[7])
    price = float(row[4])
    genre = row[11]
    if price == 0.0 and genre == 'Games':
        free_games_ratings.append(rating)

avg_rating_free_games = sum(free_games_ratings) / len(free_games_ratings)

# %%
games_social_ratings = []
for row in apps_data[1:]:
    rating = float(row[7])
    genre = row[11]
    if genre == 'Social Networking' or genre == 'Games':
        games_social_ratings.append(rating)

avg_games_social = sum(games_social_ratings) / len(games_social_ratings)

# %%
free_games_social_ratings = []
for row in apps_data[1:]:
    rating = float(row[7])
    genre = row[11]
    price = float(row[4])
    
    if (genre == 'Social Networking' or genre == 'Games') and price == 0:
        free_games_social_ratings.append(rating)
        
avg_free = sum(free_games_social_ratings) / len(free_games_social_ratings)

# Not-free apps (average)
not_free_ratings = []
for row in apps_data[1:]:
    rating = float(row[7])
    genre = row[11]
    price = float(row[4])

    if (genre == 'Social Networking' or genre == 'Games') and price != 0:
        not_free_ratings.append(rating)

avg_not_free = sum(not_free_ratings) / len(not_free_ratings)

# %% [markdown]
# ### Comparison Operators

# %%
x = -6
y = 14
z = 8.5

if x > z:
    print('x is greater than z')

if y != z:
    print('y is not equal to z')

if (z > x and z < y):
    print('z is between x and y')
# Out:
# y is not equal to z
# z is between x and y

# %%
app_price_greater_than_9 = []

for row in apps_data[1:]:
    rating = float(row[7])
    price = float(row[4])
    if price > 9.00:
        app_price_greater_than_9.append(rating)

avg_rating = sum(app_price_greater_than_9) / len(app_price_greater_than_9)

n_apps_more_9 = len(app_price_greater_than_9)

n_apps_less_9 = len(apps_data[1:]) - n_apps_more_9
