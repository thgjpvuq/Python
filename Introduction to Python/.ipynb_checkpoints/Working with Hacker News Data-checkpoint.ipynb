# %% [markdown]
# # Working with Hacker News Data
#
# ---
# We will be analyzing posts from the Hacker News Website included in the `hacker_news.csv`
#
# ---

# %% [markdown]
# We will begin by reading in `hacker_news.csv` using the csv module and removing the headers. Please note that we will store the Hacker News Data Set in a variable named `hn`.

# %%
import csv

opened_file = open('hacker_news.csv', encoding='utf-8')
read_file = csv.reader(opened_file)
hn = list(read_file)

hn[:5]
# Out:
# [['id', 'title', 'url', 'num_points', 'num_comments', 'author', 'created_at'],
#  ['12579008',
#   'You have two days to comment if you want stem cells to be classified as your own',
#   'http://www.regulations.gov/document?D=FDA-2015-D-3719-0018',
#   '1',
#   '0',
#   'altstar',
#   '9/26/2016 3:26'],
#  ['12579005',
#   'SQLAR  the SQLite Archiver',
#   'https://www.sqlite.org/sqlar/doc/trunk/README.md',
#   '1',
#   '0',
#   'blacksqr',
#   '9/26/2016 3:24'],
#  ['12578997',
#   'What if we just printed a flatscreen television on the side of our boxes?',
#   'https://medium.com/vanmoof/our-secrets-out-f21c1f03fdc8#.ietxmez43',
#   '1',
#   '0',
#   'pavel_lishin',
#   '9/26/2016 3:19'],
#  ['12578989',
#   'algorithmic music',
#   'http://cacm.acm.org/magazines/2011/7/109891-algorithmic-composition/fulltext',
#   '1',
#   '0',
#   'poindontcare',
#   '9/26/2016 3:16']]

# %% [markdown]
# We will split the first row from the data set

# %%
headers = hn[0]
headers
# Out:
# ['id', 'title', 'url', 'num_points', 'num_comments', 'author', 'created_at']

# %%
hn = hn[1:]
hn[:5]
# Out:
# [['12579008',
#   'You have two days to comment if you want stem cells to be classified as your own',
#   'http://www.regulations.gov/document?D=FDA-2015-D-3719-0018',
#   '1',
#   '0',
#   'altstar',
#   '9/26/2016 3:26'],
#  ['12579005',
#   'SQLAR  the SQLite Archiver',
#   'https://www.sqlite.org/sqlar/doc/trunk/README.md',
#   '1',
#   '0',
#   'blacksqr',
#   '9/26/2016 3:24'],
#  ['12578997',
#   'What if we just printed a flatscreen television on the side of our boxes?',
#   'https://medium.com/vanmoof/our-secrets-out-f21c1f03fdc8#.ietxmez43',
#   '1',
#   '0',
#   'pavel_lishin',
#   '9/26/2016 3:19'],
#  ['12578989',
#   'algorithmic music',
#   'http://cacm.acm.org/magazines/2011/7/109891-algorithmic-composition/fulltext',
#   '1',
#   '0',
#   'poindontcare',
#   '9/26/2016 3:16'],
#  ['12578979',
#   'How the Data Vault Enables the Next-Gen Data Warehouse and Data Lake',
#   'https://www.talend.com/blog/2016/05/12/talend-and-Â\x93the-data-vaultÂ\x94',
#   '1',
#   '0',
#   'markgainor1',
#   '9/26/2016 3:14']]

# %% [markdown]
# The Hacker News platform uses labels such as **Ask HN** and **Show HN** as tags for their posts. **Ask HN** refers to posts that wish to ask the community for a response to a question. While **Show HN** refers to posts that aim to put a member's work on display for the community to respond. With that in mind, we are only interested in posts with either of these labels. We will begin by filtering the data for the two labels then creating a separate list for each.

# %% [markdown]
# # Filtering the Data Set
#
# ---

# %% [markdown]
# Let's begin by filtering data for **Ask HN** posts. To do this we will begin by using the `.startswith()` method.

# %%
for row in hn:
    title = row[1]
    if title.startswith('Ask HN'):
        print(title)
# Out:
# Ask HN: What TLD do you use for local development?
# Ask HN: How do you pass on your work when you die?
# Ask HN: How a DNS problem can be limited to a geographic region?
# Ask HN: Why join a fund when you can be an angel?
# Ask HN: Someone uses stock trading as passive income?
# Ask HN: How hard would it be to make a cheap, hackable phone?
# Ask HN: What is that one deciding factor that makes a website successful?
# Ask HN: Is the world really short of software developers?
# Ask HN: Geolocalized public API?
# Ask HN: How to sell and idea?
# Ask HN: Doesn't matter what p. say about U, as long as  Do You Agree?
# Ask HN: What React charting lib. do you use?
# Ask HN: Is cloud storage a solved problem?
# Ask HN: Can a marketer become a tech entrepreneur and start a startup?
# Ask HN: Why would government security and hacking be any good?
# Ask HN: Are Americans really ready to give up their cars?
# Ask HN: Have you ever visited example.com?
# Ask HN: What are the best practises for using SSH keys?
# Ask HN: Know how transfer as a freelancer
# Ask HN: Where can I learn more about and contribute to the AI singularity?
# Ask HN: Payment processing for group purchases?
# Ask HN: What LaTeX editor do you use?
# Ask HN: Recommended platform for small discussion lists?
# Ask HN: Why don't online stores display return rates for individual products?
# Ask HN: Is Riak a viable alternative to Cassandra?
# Ask HN: Is there a tool to observe data and notify me about significant changes?
# Ask HN: How do you manage server ssh fingerprints?
# Ask HN: What are the best (free if possible) Wordpress themes for coding blogs?
# Ask HN: The best apps / devices for replacing testing done by a doctor?
# Ask HN: Why not openai hire using a kaggle competition?
# Ask HN: What's the best way to learn about the blockchain?
# Ask HN: If you've successfully outsourced software dev work, how did you do it?
# Ask HN: Opensource alternatives to tcpdump?
# Ask HN: What do you think about this Android app?
# Ask HN: What happened to Myra?
# Ask HN: How do you learn to be in a team
# Ask HN: Why do we put up with such restrictive IP contracts?
# Ask HN: Any bad experiences going through YC Program?
# Ask HN: How might a businesses benefit from using regular expressions?
# Ask HN: How would you monetize this site?
# Ask HN: Do you subvocalize when reading code?
# Ask HN: What to include in a code of ethics for tech recruiters/hiring managers?
# Ask HN: Would you use this service?
# Ask HN: TaskWarrior or Org?
# Ask HN: Do you think a CLI-based SaaS would be useful?
# Ask HN: What do you wish someone would build?
# Ask HN: How 000webhost.com makes money
# Ask HN: How do you get the initial traction for your web side-project?
# Ask HN: Customer demanding $2400 for dirt marks on driveway, how to handle this?
# Ask HN: Why are humanity's large systems failing?
# Ask HN: Thinking of mentoring? looking for a mentor?
# Ask HN: East African tech incubators?
# Ask HN: What do you guys use to help organize daily tasks and things to do?
# Ask HN: How to secure your internet activity (eg.emailing) when traveling?
# Ask HN: I found a flaw in a card reader. How should I report it?
# Ask HN: Is there an appropriate way to host advertisements on my site?
# Ask HN: What are you using for integration testing?
# Ask HN: How do you count unread conversations in a messaging app?
# Ask HN: About making posts
# Ask HN: Any minimal framework for small website?
# Ask HN: Alternatives for gvpr
# Ask HN: How to convert free users to paid users?
# Ask HN: What companies offer post-hire specialist training?
# Ask HN: Help with username
# Ask HN: Do you support the United States' disengagement from ICANN?
# Ask HN: People who looked down upon Node.js/JS, has ES6/etc. changed your views?
# Ask HN: Hiring at crummy wage  how to make it better?
# Ask HN: Advice on regaining passion at work
# Ask HN: How to get contributions to open source project
# Ask HN: Python: Procedural vs. Object-Oriented  what factors matter?
# Ask HN: Current state of cellular automata research?
# Ask HN: How big are your software projects and how much does the customer pay
# Ask HN: Talent management for agile teams. Site design and product feedback
# Ask HN: Best online courses on Biotech
# Ask HN: If you were paid to learn, 8 hours a day, what would be your routine?
# Ask HN: Any up to date information about the Canadian Startup Visa?
# Ask HN: Why is the FastMail mobile app so horrible?
# Ask HN: Who is going to the office hours and/or fireside chat in Buenos Aires?
# Ask HN: What do you do to relax/re-energize?
# Ask HN: Developing a 4D VR Experience. Best Tools for the Job?
# Ask HN: How do you define a Junior developer?
# Ask HN: What to do with ideas?
# Ask HN: Extracting html templates from corpus of rendered html documents
# Ask HN: Do you have any experience with burning out in the tech industry?
# Ask HN: When to ask for my first raise?
# Ask HN: What are the must-read books about economics/finance?
# Ask HN: Audio books for developers?
# Ask HN: Popular React Native apps?
# Ask HN: How to spend 6 months (personal development)
# Ask HN: Have you used eclim? How is the experience?
# Ask HN: How will YC be helping Project Include?
# Ask HN: Would you pay to keep your comms secure, ad-free, based on open tech?
# Ask HN: Domain Dispute
# Ask HN: How do you dive into a new framework/project?
# Ask HN: Best Practices for CSS in a Modern JavaScript App
# Ask HN: Have you played emoji movies the game in Google assistant?
# Ask HN: What behavioral biometric can be reliable for both auth. and anonymity?
# Ask HN: What do you feel the best source of data / research based news source?
# Ask HN: Top rules as a good-developer to stay on top of your game
# Ask HN: Anyone interested in connecting with me?
# Ask HN: How to get a high load on a website in a short time?
# Ask HN: What products have you used regularly for years?
# Ask HN: Anyone interested in connecting with a mentor?
# Ask HN: Is anyone having problems with Couchbase?
# Ask HN: 2017 Software Engineer Winter Internships in US/UK with Visa Sponsorship
# Ask HN: How do you manage your personal software projects?
# Ask HN: What are the potential pitfalls of stock options?
# Ask HN: How would you know if there is a virus that has infected your MAC?
# Ask HN: Fulltime software engineers over 250k, how'd you get there(updated)?
# Ask HN: Startup lottery
# Ask HN: Review my startup  MD in your pocket
# Ask HN: Best way to crunch 3 weeks work into 2?
# Ask HN: Technology related visit/holiday
# Ask HN: Top 5 rules as a developer to stay in top your game?
# Ask HN: How are you making JavaScript websites (not webapps)
# Ask HN: is there a cross-device calendar with tasks outside of Outlook and iOS?
# Ask HN: Do I do my masters in CS if it means staying an extra semester?
# Ask HN: Will the future have several more programmers or a few excellent ones?
# Ask HN: What is the current scientific opinion on the works of Stuart Kauffman?
# Ask HN: How would you improve HN?
# Ask HN: How to solve chicken and egg problem?
# Ask HN: Which areas of math are practical to programming/algorithms and why?
# Ask HN: Settle for less salary or change to make more in prime years
# Ask HN: What is the necessary knowledge to build a chatbot?
# Ask HN: TuSimple achieves state-of-the-art results on KITTI and Cityscapes
# Ask HN: How to build something better than HN?
# Ask HN: Why don't web apps make use of right click?
# Ask HN: Google Apps vs. Fastmail
# Ask HN: Which podcasts do you listen to regularly?
# Ask HN: My work permit was just denied because I don't have a degree. Can I
# Ask HN: WebRTC onion routing between Facebook friend circles
# Ask HN: To expose a security flaw or not? (at a company where I Interviewed)
# Ask HN: I created a SaaS platform, but I have no idea what to do with it
# Ask HN: How to Grow Your Site?
# Ask HN: Recommend an IDaaS/Login provider?
# Ask HN: Any distributed-db has redis-like custom c modules/data-types?
# Ask HN: Thinking about making a website to teach people Excel. Good idea?
# Ask HN: How do I build upon what HN did for OldGeekJobs.com?
# Ask HN: doesn't the iPhone already have bokeh?
# Ask HN: Suggestions for email provider separate from vps
# Ask HN: What do you use for company-wide documentation
# Ask HN: How to re-open all browser tabs in a different machine
# Ask HN: Best way to bootstrap?
# Ask HN: Should I rebrand my web app?
# Ask HN: Your experience with a dedicated test team?
# Ask HN: How illegal does the code have to be before you refuse to deploy?
# Ask HN: JavaScript Library for creating Simulink-like charts
# Ask HN: I created a scraper, now I think how to utilize scraped data
# Ask HN: What are today's End to End encryption solutions for non tech people?
# Ask HN: Smalltalk, Platonic idea world and Giordano Bruno memory techniques
# Ask HN: Why do you really hate ads?
# Ask HN: What are some good Crowdsourced Testing Platforms?
# Ask HN: Do you have any experience with burning out in the tech industry?
# Ask HN: Is facebook deliberately preventing/discouraging users from logging out?
# Ask HN: Donate to Republican/Democratic party via Stripe
# Ask HN: What simple finance tool for a small business?
# Ask HN: Solo developer on a side project, where to focus?
# Ask HN: Why does Booking.com have such bad reputation?
# Ask HN: What are some iOS apps with the best design?
# Ask HN: Of Introverts, the Open Office, and ADHD
# Ask HN: How did you learn coding
# Ask HN: Stripe for 10k plus transactions?
# Ask HN: Deep learning attack vectors
# Ask HN: How is the Udacity's Nanodegree Plus worth it?
# Ask HN: After Hour Meetings
# Ask HN: Best way to get started in a different language
# Ask HN: File sharing for startup
# Ask HN: New OSS Projects: Go or Java?
# Ask HN: Self-taught novice to junior dev position?
# Ask HN: Which is the smallest size CNN for Pedestrian Detection?
# Ask HN: Do you worry that your product will be killed by one of the tech giants?
# Ask HN: Who owns the Internet?
# Ask HN: What are your problems in Cloud?
# Ask HN: How would you learn software engineering if you had no responsibilities?
# Ask HN: Book on how to build software collaboratively and lead the process?
# Ask HN: Those with small side projects, where did you find part-time talent?
# Ask HN: When is it considered too early to start applying for S.E jobs?
# Ask HN: Online communities for founders or operators
# Ask HN: Is there anything I can do to prevent burnout?
# Ask HN: Does the film industry use stock options for compensation?
# Ask HN: Doesn't Chrome new interface look more *fragile*?
# Ask HN: Software for helping visually impaired persons?
# Ask HN: Time for *cheap* e-notebooks?
# Ask HN: How to reduce accent?
# Ask HN: How do you read?
# Ask HN: Should I give equity to early employees?
# Ask HN: Where in European Union should I move to found a startup?
# Ask HN: What are the top ten hundred words used on HN and SO?
# Ask HN: I'm Looking for Interview Question about Java Around Web Development
# Ask HN: What would make your life better?
# Ask HN: In what areas are NoSQL Databases beneficial over Relational Databases?
# Ask HN: Why isn't there a `setDay` method on the Date prototype?
# Ask HN: Where do you go to get recruiters to find you a job?
# Ask HN: Why do mail clients not support modern standards?
# Ask HN: Articles / Stories on failed experiments
# Ask HN: I am 21 and lost
# Ask HN: What's the next big thing that will exceed hiring capacity?
# Ask HN: Moving to US from the UK
# Ask HN: Is there a URI for identifying points in time?
# Ask HN: How has your experience with Amazon Prime been?
# Ask HN: Can 32-bit Interact with 64-bit?
# Ask HN: New Server on every SSH connection?
# Ask HN: How to get certificate of employment on a startup?
# Ask HN: What has been your experiences with using a terminal on mobile phones?
# Ask HN: How do you track scientific articles of your interests?
# Ask HN: Did you spend more on software or saas this year? And your business?
# Ask HN: How long did you work on a side project until it was your full time job?
# Ask HN: Getting back to work after a brain tumour
# Ask HN: Malware 32-bit
# Ask HN: How relevant are Master's degrees in tech today?
# Ask HN: How early is too early to move on from first job?
# Ask HN: Is there a way to turn off voicemail parsing in IOS10?
# Ask HN: What are you usually doing when you have an 'insight'?
# Ask HN: Simplest way to build a REST API?
# Ask HN: Moving from academia to tech?
# Ask HN: What problems can techies solve to help world?
# Ask HN: Any resources on how to move existing premise applications to cloud?
# Ask HN: How do you monitor server logs
# Ask HN: What are some examples of well written C/C++ codebases?
# Ask HN: What are the big recent tech companies in India other than Olacabs?
# Ask HN: What is your favourite Roald Dhall book?
# Ask HN: Any one ever training a NN on a kinect data to guess depth?
# Ask HN: Would you join a social network run by a non-profit?
# Ask HN: Best MOOC or Tutorial After Reading Nate Silver's Signal and the Noise
# Ask HN: What does Facebook actually do these days?
# Ask HN: Trying to Learn Delphi 7
# Ask HN: Anyone already using the new GitHub Projects feature? Care to share?
# Ask HN: Simple database/key-value store web API for throwaway projects?
# Ask HN: Has anyone been hired by the big 4 companies from outside the US?
# Ask HN: Why are we building self driving cars to navigate based off human signs
# Ask HN: How to get into $300k+ club?
# Ask HN: How do you decide your cloud provider
# Ask HN: Is tutorialspoint.com a good website to learn languages and DSA?
# Ask HN: Would you sign up if a Phone Number is required?
# Ask HN: I am torn between whether I should do MBA or not. Thoughts?
# Ask HN: Are plain resumes still relevant today?
# Ask HN: What would you want to see in a DevOps monitoring handbook?
# Ask HN: Are resold barcodes a scam?
# Ask HN: What is the most novel program you saw?
# Ask HN: How to seek mentorship?
# Ask HN: Help me chose a startup vs. contractor
# Ask HN: How to find results removed from Google under 'right to be forgotten'?
# Ask HN: What error-handling patterns have you found useful for large code-bases?
# Ask HN: OldGeekJobs Evolving the MVP
# Ask HN: Is it possible for someone to not be cut out for software engineering?
# Ask HN: Master vs. Udacity nanodegree
# Ask HN: HN Content Filter Stats
# Ask HN: How do you describe organisation wide data structures
# Ask HN: Website or software to teach young kids to type and mouse
# Ask HN: What problem would you pay for a solution?
# Ask HN: Best route from developer to pentester
# Ask HN: How (not) OK is it to analyze text from SciFi books using torrents?
# Ask HN: Would your company fire you when you place orders automatically?
# Ask HN: Feedback for Interview Survey?
# Ask HN: Do I need to inform visitors about LocalStorage?
# Ask HN: Are these signs of a failing startup
# Ask HN: Declining NDAs
# Ask HN: Nested Virtualization / NAT Supported VPS
# Ask HN: Can you help this quadriplegic organise their medical information?
# Ask HN: What's your best marketing automation techniques?
# Ask HN: How do you motivate yourself?
# Ask HN: Can I be public about a interview process with a Company?
# Ask HN: Which language for interacting with AWS?
# Ask HN: Tutorial / reference for building db backed web apps with express/node?
# Ask HN: Might Apple be botching their UI design lately, or is it just me?
# Ask HN: What do you use to make your presentations for talks?
# Ask HN: Selling IDEs for proprietary platforms?
# Ask HN: Is Answering Questions on Stackoverflow help us to grow in our carrier?
# Ask HN: Finding a partner for a unique request
# Ask HN: What's a simple app/software that made a lot of money?
# Ask HN: What do you need apply to NFx Guild after being invited?
# Ask HN: Any suggestion about server administration tool for solo developer?
# Ask HN: How to talk to the boss about promotion
# Ask HN: How much would you pay for something like Calibre that Doesn't Suck?
# Ask HN: Anything Like Kapa99 but for Ghostwriting?
# Ask HN: Strategies for porting native code to another OS?
# Ask HN: Best approach to getting first job in Bay Area?
# Ask HN: What books are you reading this week?
# Ask HN: What is your AWS DynamoDB monthly cost?
# Ask HN: 5 most important problems for a 22 yo to work on
# Ask HN: How are teams sharing secrets?
# Ask HN: Why aren't their taxes in the country the patent is held?
# Ask HN: Whats the State of the Art in Due Dilligence and Auditing
# Ask HN: Health insurance options for founders while bootstrapping
# Ask HN: What code makes you happy?
# Ask HN: How to justify the bloat of modern JavaScript frameworks?
# Ask HN: What is the cleanest code sample you've seen?
# Ask HN: What's a good software/interface to consume mailing lists?
# Ask HN: Automatically download components that can't be distributed?
# Ask HN: How can I get Google to reinstate my adsense account?
# Ask HN: What's the most frustrating part about saving money?
# Ask HN: Hosting companies providing gratis hosting to free software projects?
# Ask HN: What features make a good blogging platform for you
# Ask HN: As driverless increases, Uber should disappear, what do you predict?
# Ask HN: Devices for multidimensional input of continuous variables by human
# Ask HN: First time managing an internal team, how can I be a successful boss?
# Ask HN: Most impressive SaaS landing page?
# Ask HN: Would anyone be interested in a modular BSP(Board Support Packages)
# Ask HN: Pricing dead zone: 300$-3000$
# Ask HN: What are the hottest startups related to beer / brewing?
# Ask HN: Did IT matter?
# Ask HN: Suggestion on Automated Testing Suit(E2E) for NodeJs/ReactRedux App?
# Ask HN: What does your stack at work look like? What other tools do you use?
# Ask HN: What is the most pseudo-technical thing you've heard in your workplace?
# Ask HN: Angular2 UI Frameworks ng-bootstrap, ng2-bootstrap or material2
# Ask HN: How to become a Unix/Linux power user?
# Ask HN: Do I need to be an expert on some technology to write a book on it?
# Ask HN: Personal C&C software/hardware?
# Ask HN: Is Intel Xeon Phi many-core processor vaporware?
# Ask HN: Who wants to connect talented high schoolers with internships?
# Ask HN: Are there any APIs that expose small claims court data?
# Ask HN: Is there a solution to the Bitcoin blockchain growth problem?
# Ask HN: Legal for companies to chatbot and not identify?
# Ask HN: Use Appengine or Stripe? How are your card declined rates?
# Ask HN: Boilerplates for quick prototyping of business ideas
# Ask HN: What would you like to learn in your spare time?
# Ask HN: Can you share how you sought mentorship or mentored
# Ask HN: YC startup school 2016 meetups?
# Ask HN: Making closed-source software that handles personal data illegal?
# Ask HN: Are Bitcoins untraceable to a real identity?
# Ask HN: Which Java framework will replace Spring?
# Ask HN: Why all the software labeled as robots now?
# Ask HN: How do I keep my skills up to date?
# Ask HN: Stay in touch with professional friends or former colleagues
# Ask HN: How much time do you spend reading VS doing/coding?
# Ask HN: Guidance on dealing with a bug bounty claim
# Ask HN: How to get rid of laziness to read?
# Ask HN: Have there been instances of US fed govt acting on illegally gained info?
# Ask HN: How to get computer tech support clients?
# Ask HN: What is a good multi-user solution for encrypted cloud data
# Ask HN: What's up with Starfighter?
# Ask HN: What are your favorite sayings?
# Ask HN: What's the biggest life lesson you've learned?
# Ask HN: Is Google Apps Down?
# Ask HN: Other worthy news/discussion communities?
# Ask HN: What RDBMS GUI client would you recommend
# Ask HN: Does asking Why am I being downvoted get upvotes?
# Ask HN: What are some well documented ReactJS applications?
# Ask HN: How can I find a full time job?
# Ask HN: Dropbox down / DNS resolution issue?
# Ask HN: What's your favorite HN post?
# Ask HN: Is Swift worth learning if I'm not into iOS development?
# Ask HN: YCombinator.com down for everyone?
# Ask HN: If you were to reinvent the web, how would your HTML/CSS/JS look like?
# Ask HN: How to Learn OOP
# Ask HN: Categories for news on HN?
# Ask HN: If HN were a standalone company, what would it be valued at
# Ask HN: How do you validate business ideas before investing work
# Ask HN: How to test or proove logic programming?
# Ask HN: Has anyone ever crawled over a billion pages? How much did it cost?
# Ask HN: Can anyone recommend debt collection cloud software?
# Ask HN: AirPod Security Questions
# Ask HN: Anyone attending YC Startup School 2016? Let's know each other
# Ask HN: Will i need separate earphones for my iPhone 7 and my Macbook?
# Ask HN: Why is linking to paywalled articles so common here?
# Ask HN: What would you like to see in an improved Who is Hiring site?
# Ask HN: Does your company find value in exit interviews?
# Ask HN: Best native postgres client for Mac
# Ask HN: Can I become a programmer with a Computer Programmer Analyst course?
# Ask HN: General advice to grow my network
# Ask HN: How do I systematically learn computer science?
# Ask HN: Should you tell the story behind your work?
# Ask HN: Is there any tool for testing a site's CSS specificity etc..?
# Ask HN: Data visualization consultant
# Ask HN: Teaching Assistant bot for GitHub
# Ask HN: Find an accountant for small dev shop?
# Ask HN: Do banks use OLTP or event sourcing to process money transactions?
# Ask HN: Would you pay a service that enables you to send updates to visitors
# Ask HN: Would you be interested in an embeddable, lightweight subset of Python?
# Ask HN: Are new posts getting less frequent on HN?
# Ask HN: Secure file sync service with mobile clients?
# Ask HN: What do I do if my raise-request is declined?
# Ask HN: Why is camel case a standard in JavaScript ?
# Ask HN: How does Apple keep its secrets?
# Ask HN: Run discovery of hypermedia APIs
# Ask HN: Why do human babies cry?
# Ask HN: Most impressive wearable technologies?
# Ask HN: Middle way between being the boss and being a slave?
# Ask HN: Why would a botnet access my server like that?
# Ask HN: What's the easiest way to make a custom Captive Portal?
# Ask HN: Alternatives to Namecheap and Godaddy
# Ask HN: Could war be avoided by nuclear scientists defecting from North Korea?
# Ask HN: What was your eureka moment while programming?
# Ask HN: Compare AutoRest, Apimatic and Swagger Codegen
# Ask HN: Do coding boot camps get people jobs/careers without a degree?
# Ask HN: Why doesn't Paul Graham give more public talks?
# Ask HN: Wanting to become a programmerkeep running into problems
# Ask HN: What should I do?
# Ask HN: What is the best way to enter VC?
# Ask HN: Easiest way to set up a static HTTPS site in 2016?
# Ask HN: Is Apple about to kill the Macbooks?
# Ask HN: How to be comfortable being uncomfortable?
# Ask HN: How common are one-way attorney fees in a non-compete?
# Ask HN: Is it ageist to judge an older applicant for lack of achievement?
# Ask HN: How do I ensure access to my API only from my webapp
# Ask HN: Suggestion for new team lead
# Ask HN: Any nicer alternatives to Mint for personal budgeting?
# Ask HN: Is Java/.NET a better choice for inhouse GUI's instead of web stack?
# Ask HN: Finding Help for New Startup?
# Ask HN: Do you use any dashboard to visualize your KPIs and metrics?
# Ask HN: How to you browse, store, sync, and backup your family photos?
# Ask HN: If you had only 10^N dollars for a cause, what would you choose and why?
# Ask HN: Can we talk about Satoshi Nakamoto's identity?
# Ask HN: Resources for software managers?
# Ask HN: How do you handle photographs across a distributed company?
# Ask HN: How do you feel about fixed navbars?
# Ask HN: What is the best way to connect robots in the classroom?
# Ask HN: Is there payment ecommerce gateway without VAT?
# Ask HN: Sticky headers break pg-down on web
# Ask HN: What do you predict for front end web development for the next 5 years?
# Ask HN: Hacker news for machine learning and/or deep learning
# Ask HN: What to look for in a job candidate's GitHub profile
# Ask HN: I'm 23, and I dislike my job as a software engineer
# Ask HN: How best to describe my service?
# Ask HN: How can I become a proper Project Manager from a Programmer?
# Ask HN: Does JavaScript have race conditions?
# Ask HN: What are most inherently secure OS's and why? The opposite and why?
# Ask HN: Have you ever been hurt by a lack of privacy?
# Ask HN: Is web programming a series of hacks on hacks?
# Ask HN: How do you get notifications if something doesn't happen?
# Ask HN: Strange bug workarounds?
# Ask HN: Beyond internships, what should a CS major focus on?
# Ask HN: Which language(s) should I learn to do one-man projects and earn money?
# Ask HN: Why do engineers as a group allow opaque offer letters?
# Ask HN: Whiteboard-driven development?
# Ask HN: How to forward client port number used?
# Ask HN: Are there any startups trying to cure autoimmune disease?
# Ask HN: What good books have you read lately?
# Ask HN: Simple database/key-value store web API for throwaway projects?
# Ask HN: Where can I find AI/ML math resources?
# Ask HN: How is ruby web dev centered so much vs. Python having flask and Django?
# Ask HN: Why do all editors have line numbers disabled by default?
# Ask HN: Any good weight loss plans not too demanding for a typical dev?
# Ask HN: React Native vs. Xamarin workflow and tooling?
# Ask HN: What Are the Best Routes for Senior Full-Stack Software Engineers?
# Ask HN: How do you find advertisers for your product outside of ad networks?
# Ask HN: What will be the effects of the upcoming rise of AI and Automation?
# Ask HN: What will HN be able to do in 10 years from now?
# Ask HN: System76 Ubuntu laptops?
# Ask HN: Embedded?Firmware topics for interviews
# Ask HN: Tell me about modern databases
# Ask HN: My game is growing fast. What should I do?
# Ask HN: How to deal with a founder that won't leave his job (maybe)?
# Ask HN: How to deal with a founder that won't leave his job (maybe)?
# Ask HN: Any projects which tweak c++ syntax? (Transpilers, etc.)
# Ask HN: How do you organise your codebase on your private machine?
# Ask HN: Resources on how to build internal/enterprise tools?
# Ask HN: I just finished building a PaaS prototype and I need your help
# Ask HN: Has anyone here successfully applied to Stripe Atlas?
# Ask HN: Is anyone running Kubernetes with Persistent Volumes in production?
# Ask HN: How can we recreate the world wide web?
# Ask HN: Why does the Enhancement Suite for Chrome no longer show upvotes?
# Ask HN: Best devs to follow on Twitter?
# Ask HN: Can you suggest some IOT project to work on for undergraduate CS course
# Ask HN: What's the future of your digital skills?
# Ask HN: can we fix the tiny HN font size?
# Ask HN: Why hasn't anyone made a mobile app for Phabricator?
# Ask HN: Laravel, how does it compare to frameworks like Rails, express?
# Ask HN: Does this legal programming language exist?
# Ask HN: What do you guys think of Jacque Fresco's ideas?
# Ask HN: Most excited during a work crisis?
# Ask HN: Real-time Altitude API useful?
# Ask HN: Equivalent of Stripe Atlas in Europe (EEA)
# Ask HN: Modern Web Dev on the JVM  How does the stack and tooling look like?
# Ask HN: What makes a good startup CEO?
# Ask HN: A list of software names to help name new software without name clash
# Ask HN: What's a practical way to learn microeconomis?
# Ask HN: Teaching a class on Python at university  suggestions?
# Ask HN: Dropbox alternative with best UX?
# Ask HN: What ad exchange is Reddit using for their mobile app?
# Ask HN: Optimizing business processes and taking a cut  reading tips?
# Ask HN: Anyone forked and stil developing wd (GitHub.com/admc/wd)
# Ask HN: Other companies with an asynchronous, text-only interview process?
# Ask HN: What's your backup plan for 2Factor authentication if you lose your phone
# Ask HN: How do you choose which frameworks to use for a side project?
# Ask HN: Who needs non-technical contributors?
# Ask HN: What's your dream as a programmer?
# Ask HN: Where to go next with my mobile marketing website
# Ask HN: How do you manage your landing page?
# Ask HN: Considering a bootcamp. Anyone familiar with Bitmaker?
# Ask HN: What are the things you need or like to have which yet doesn't exist
# Ask HN: What's the point of making smartphones slimmer and slippery?
# Ask HN: Company acquired by private equity firm. What to expect?
# Ask HN: Which widely popular software or app today will be irrelevant in 2032?
# Ask HN: If you could work for any company who would it be any why?
# Ask HN: Low cost source code escrow
# Ask HN: Is this a fast page for mobiles?
# Ask HN: Does the x.ai wait in line feel like a marketing ploy?
# Ask HN: What do you REALLY look for in a new position?
# Ask HN: What is the most frustrating part about working as a contractor?
# Ask HN: How to deal with a superior who is unresponsive to a security issue?
# Ask HN: How does your team do internal documentation?
# Ask HN: Git Issues Email Report Generator
# Ask HN: What's broken in healthcare and how would you fix it?
# Ask HN: How to get high school students enthused about software engineering?
# Ask HN: How do you deal with bugs in software you sell?
# Ask HN: Internships open to non-US students?
# Ask HN: How effective is the Windows 10 Ubuntu shell?
# Ask HN: Anyone with music projects looking for co-founders?
# Ask HN: How are you managing your career?
# Ask HN: Is every market saturated?
# Ask HN: What happened to Facebook graph search?
# Ask HN: Why browsers don't verify cheksums of downloaded content?
# Ask HN: How would you hack fundraising in SFA during 7 days
# Ask HN: Google Analytics Realtime down for me
# Ask HN: Clojure vs. Haskell?
# Ask HN: Architecturing a life
# Ask HN: Resources for developing multi-platform native code libraries?
# Ask HN: Payroll Sync, how does it work?
# Ask HN: Something with more layout control than Graphviz?
# Ask HN: Remote-only job boards
# Ask HN: What's the fastest way to deploy a blog?
# Ask HN: CDN or npm?
# Ask HN: VR the next platform?
# Ask HN: Rendering transparent overlay in cross-platform desktop application?
# Ask HN: A website where you can store, share, and "run" your coffee/tea recipes?
# Ask HN: How to buy Vested stock when leaving start up?
# Ask HN: Freelance or Full-time?
# Ask HN: New MacBook?
# Ask HN: Can a mesh network replace fiber?
# Ask HN: Any special growth hacking tricks for B2N?
# Ask HN: What's your experience with human errror in cybersecurity?
# Ask HN: When did the terms Front-End, Back-End, and Full-Stack become prevalent?
# Ask HN: How can I convince people that UX improvements are valuable?
# Ask HN: What are the top podcasts you listen to for marketing/growth?
# Ask HN: Web development agency top tips for getting and holding onto clients
# Ask HN: What Cloud storage provider(s) do you use?
# Ask HN: Is job at McKinsey or other similar corporates only for Capitalist?
# Ask HN: How do you deploy your software in multiple countries?
# Ask HN: How front-end interviews at Google look like?
# Ask HN: Should being a conference speaker expose your reputation to destruction?
# Ask HN: What are the coolest remakes of retro computing devices?
# Ask HN: Self-taught or college education?
# Ask HN: Why Twitter
# Ask HN: What happened to code generation tools?
# Ask HN: Do contract jobs still exist in financial services in London?
# Ask HN: Junior engineer at HPE transferred out of development, what now?
# Ask HN: Stack for creating web app also hosted on Windows app
# Ask HN: Photo cataloging programs
# Ask HN: Diversity Survey
# Ask HN: What books did you read as a kid that inspired you?
# Ask HN: What are your favorite articles/blog posts of all time?
# Ask HN: The next generation web framework?
# Ask HN: Examples of advanced Django API implementations?
# Ask HN: What compensation should a Series-A company give to an advisor
# Ask HN: Alternatives to Gusto for someone self-employed
# Ask HN: WTF is wrong with the Canadian visa form?
# Ask HN: How to comunicate more clearly my project idea?
# Ask HN: Office merge. They have a pet policy. I'm scared of dogs. What can I do?
# Ask HN: Thoughts on a simple business idea
# Ask HN: Any interesting conferences coming up in the fall of 2016?
# Ask HN: If finding great engineers is so hard, then why
# Ask HN: Beside Java what languages have a strong tooling/IDE ecosystem on Linux?
# Ask HN: Company Doing 6 Month Crunch
# Ask HN: How would you stay updated with all the engineering blogs?
# Ask HN: What goals do you have in work or how do you find meaning in work?
# Ask HN: Working as contractor in UAE
# Ask HN: How Are the YC HW Startups Doing?
# Ask HN: VCard service with API / self-hosted
# Ask HN: What percentage of your salary are you paying to health insurance?
# Ask HN: How to convince partner to sell
# Ask HN: What would your ideal jobs board have/do?(Developers and Employers of HN)
# Ask HN: Should flag have a confirmation dialog?
# Ask HN: Suggest Some Websites Related to Internet Privacy and Net Neutrality
# Ask HN: Any Android app to read/comment/vote on both HN and Reddit?
# Ask HN: How do you value a website that is on the first page of Google?
# Ask HN: Recommendations for a startup bank account (UK)
# Ask HN: Should I force myself to touch type?
# Ask HN: Clothes for children related to the IT world
# Ask HN: Best way to secure on-premise servers?
# Ask HN: Linux host with KVM/PCI passthrough for gaming and native CUDA for work
# Ask HN: Is 1password safe?
# Ask HN: What is the name of this business model?
# Ask HN: What is the most economical method of developing iOS apps?
# Ask HN: What is the value of a website that is on the first page of Google?
# Ask HN: What once useful product/services have you stopped using?
# Ask HN: What's the condition for a show hn to get from shownew to main show?
# Ask HN: What stack are you using for your project lifecycle?
# Ask HN: Can I Re-Share Open Source ebook from my portal?
# Ask HN: Haskell ARM Continuous Integration Service
# Ask HN: How do you go about learning new stuff?
# Ask HN: Scientific evidence for anti aging skin care product effectiveness?
# Ask HN: When is flirting at the workplace sexist?
# Ask HN: What in IT shouldn't exist?
# Ask HN: What dataset could I collect while traveling extensively?
# Ask HN: Learning resources for a noob?
# Ask HN: How do you manage all your online passwords?
# Ask HN: API for determining aesthetics in photos?
# Ask HN: Which language should be taught for Web?
# Ask HN: Working off of a bootable USB drive
# Ask HN: Working in Sweden?
# Ask HN: Work hard party harder a good moto?
# Ask HN: How can I be productive interning remotely?
# Ask HN: I created a new GitHub project, and I need some suggestions and ideas
# Ask HN: Where do you go for learning about health and well-being?
# Ask HN: What should I do as a forever alone software engineer?
# Ask HN: Open source version for key-value store of life?
# Ask HN: JavaScript library for progressively revealing explanation/elaborations?
# Ask HN: How to find office hours or startup mentorship?
# Ask HN: Where can I find a standard shareholder agreement for a company?
# Ask HN: Best hosting for intensive computation?
# Ask HN: Isn't machine learning just a special case of curve fitting?
# Ask HN: How did you keep improving your typing speed after 100 WPM?
# Ask HN: Labour of love projects
# Ask HN: Can you help with a report on email marketing?
# Ask HN: Unix system version information
# Ask HN: Business Card Feedback?
# Ask HN: Random email generator?
# Ask HN: What has been the effect of wage transparency in Scandinavian countries?
# Ask HN: Christmas Gift Ideas to Introduce Kids to Programming/Tech?
# Ask HN: What is your preferred method of personal password storage?
# Ask HN: SaaS Stack advice for non web-dev
# Ask HN: Setting up a captive portal
# Ask HN: How do you get traction with a product that's subtle?
# Ask HN: Can a blockchain do this?
# Ask HN: What would you improve about human body?
# Ask HN: How to reach your potential as a Developer
# Ask HN: What is the most disappointing technical skill you possess?
# Ask HN: Are you happier with your day to day life after starting to freelance?
# Ask HN: Why is inter-device file sharing still a hassle?
# Ask HN: What's the best metasearch engine?
# Ask HN: What is the most surprising technical skill you possess?
# Ask HN: What are best ways to prepare for RHCA/RHCE
# Ask HN: Why should open source support be free? I don't think it should.
# Ask HN: How an experienced welder can be useful for the Internet 2.0 companies?
# Ask HN: How do you run meetings at your startup?
# Ask HN: How to prepare for a leadership role?
# Ask HN: Any unfinished side projects to give away?
# Ask HN: Improving the Hacker News Frontpage Algorithm
# Ask HN: Is wanting to be a VC a red flag for a startup hire?
# Ask HN: In what ways could the HN frontpage algorithm be improved?
# Ask HN: How Ethereum (smart contract) works?
# Ask HN: What does an electrical engineer actually do at work?
# Ask HN: Ways to kill clickbait?
# Ask HN: Setting up a captive portal
# Ask HN: What are some amazing open source Data Science projects?
# Ask HN: How to Access Bitbucket Without Atlassian Cloud?
# Ask HN: Parents how do you limit your kids time playing the computer?
# Ask HN: Breadth vs. Value in product design
# Ask HN: Review our startup: Eventil, helping organise tech events
# Ask HN: What is the best way of using Linux on a laptop (currently)?
# Ask HN: Why has HackerNews succeeded despite the rise of Reddit?
# Ask HN: How much maintenance time do your side projects require?
# Ask HN: Whats the Status of the Hacker News Write API?
# Ask HN: Would you want to watch YC's Stanford Course together online?
# Ask HN: Will there be a better Google?
# Ask HN: How do you use HN?
# Ask HN: Working in Sweden?
# Ask HN: How do you decide, link or comments
# Ask HN: What are good alternatives to Spotify? Gapless playback is awful
# Ask HN: Any back-end devs swiched to front-end or a mix? What's your experience?
# Ask HN: What is the best open source OCR software supporting multiple languages?
# Ask HN: Events before/after Startup School?
# Ask HN: Is there any CRM for mobile games?
# Ask HN: Code School for web dev/stack basics?
# Ask HN: Non-tech books that have helped you grow professionally?
# Ask HN: Why does this app cost $92M to build and $93M/year to maintain?
# Ask HN: Confirmed developer running low, what's the quickest way to make money?
# Ask HN: How much of your time is spent in meetings?
# Ask HN: How do you deal with disk space and docker deployments?
# Ask HN: Which CRM do you use? Any open source / self-hosted?
# Ask HN: What do you want to knowithlearn about Emotional Intelligence?
# Ask HN: Code review tools
# Ask HN: Your monthly (side) project update
# Ask HN: How do you optimize your time for side projects?
# Ask HN: How would you design a voting system?
# Ask HN: What's a good smartphone that you can buy today?
# Ask HN: Experience with a think tank?
# Ask HN: Where do you go for civil discussion on the Internet?
# Ask HN: Functional and Typed Filesystem?
# Ask HN: Search jobs
# Ask HN: What underrated GitHub repos you found in August?
# Ask HN: Hacker's Guide to Social Media Management?
# Ask HN: Generating reports on time series data without killing performance?
# Ask HN: What technology to use for a small business with web and mobile clients
# Ask HN: Good resources for new immigrants on how to settle?
# Ask HN: Where Are the Cheap Remote Desktop Services?
# Ask HN: Do you use CSRF protection in your forms?
# Ask HN: Good resource on starting a buseness in the US?
# Ask HN: Simple client websites  What do you use?
# Ask HN: A reasonable deployment solution for small-scale kiosk apps?
# Ask HN: Who is hiring vs. Who Wants to be hired
# Ask HN: Who needs contributors?
# Ask HN: Who wants to be hired? (September 2016)
# Ask HN: Freelancer? Seeking freelancer? (September 2016)
# Ask HN: Who is hiring? (September 2016)
# Ask HN: Elasticsearch vs. SOLR?
# Ask HN: Are any of you familiar with Sword of Glass' history?
# Ask HN: How do you scale complexity?
# Ask HN: Scaling a tech team
# Ask HN: What is your favorite way to learn?
# Ask HN: Any programmers here suffering or suffered from hyperhidrosis?
# Ask HN: How do you find people who need applications built?
# Ask HN: Opportunities to study abroad without a previous degree?
# Ask HN: Engaging inactive users
# Ask HN: Where/how do you test apps on physical devices pre-release?
# Ask HN : About risks
# Ask HN: Admin girl wants to get into radio engineering
# Ask HN: Submitting HN comments
# Ask HN: Am I shadow-banned?
# Ask HN: How Do Karma Points Work?
# Ask HN: Which communication tool do you use to remotely run your business?
# Ask HN: Split screens for web browser?
# Ask HN: What problems are solved best with Haskell?
# Ask HN: Google Container Engine vs. Heroku vs. Beanstalk?
# Ask HN: How are world class data teams structured?
# Ask HN: Do we have a case against Facebook for infringement?
# Ask HN: Showing unread comments in Chrome
# Ask HN: Why Google stops printing results after page #1,000
# Ask HN: Blackboxing an on-premises application
# Ask HN: Anyone interested in having their Code painted (oil on canvas)?
# Ask HN: Do you rely more on data or intuition when making product decisions?
# Ask HN: Co-founder woes. Pl advice
# Ask HN: Whats the best way to inline external script tag?
# Ask HN: Revenue/Subscribers estimation algo for competitive intelligence?
# Ask HN: Specializations within IT
# Ask HN: When to settle down (as a guy)?
# Ask HN: Any tools/frameworks to read and comprehend articles?
# Ask HN: How to convert US salary to a Canadian contractor salary? (remote)
# Ask HN: Kubernates on Vsphere
# Ask HN: Why not offer flexible pricing for Saas
# Ask HN: Best trick for your side project?
# Ask HN: What C# books are highly recommended for professional .NET developers?
# Ask HN: List of sites most annoyed by adblocker
# Ask HN: How Did You Escape 9 to 5?
# Ask HN: How do you manage per-service emails with aliases?
# Ask HN: What do you do to achieve your financial independence/early retirement?
# Ask HN: Where can I learn about deploying production environments?
# Ask HN: What is the business model of tawk.to?
# Ask HN: How to profile Android GC
# Ask HN: How are credentials managed at your company?
# Ask HN: Did you know that searching Facebook reveals your identity?
# Ask HN: What is your recommended password manager?
# Ask HN: Do you use Docker v.1.12 swarm mode successfully in production?
# Ask HN: What is your favourite conference?
# Ask HN: How do you deal with performance anxiety during interviews?
# Ask HN: Fired from a company I loved- seeking advice
# Ask HN: What is the evolutionary explanation for having a song stuck in my head?
# Ask HN: How would I get started with systems programming?
# Ask HN: Would you liked if your NIS https login was served with Google js?
# Ask HN: I want to write a niche (e)book, but don't know where to start
# Ask HN: How did South Korea raise in tech so quickly
# Ask HN: How can I get my hairstylist's contact info?
# Ask HN: Leave new job after one month?
# Ask HN: What should I ask Elon Musk for HTBTF?
# Ask HN: How does one go from junior engineer to mid-level in less than a year?
# Ask HN: Handle my two SaaS platforms as one single brand or 2 independent ones?
# Ask HN: Small town lots of FiOS infra. no residential FiOS keep pushing?
# Ask HN: Is the Win 7 experience better since the free upgrade to 10 expired?
# Ask HN: Allowance for for fun post and comments?
# Ask HN: What are the tax advantages of incorporating vs. an LLC?
# Ask HN: Anybody using web components (or Polymer) in production?
# Ask HN: What is equivalent of Nextdoor for business?
# Ask HN: Best book on structuring data for large program
# Ask HN: Root login/Ansible best practices?
# Ask HN: Can a start up succeed with a CEO that no one wants to work for?
# Ask HN: Best EU country to incorporate a startup?
# Ask HN: How authentication works at HN?
# Ask HN: Advice on failing company
# Ask HN: Do you read a Golang's package source before you import it?
# Ask HN: How to manage transition out of startup I founded?
# Ask HN: How do I perform given a 1 month probation period?
# Ask HN: How do I find out if a company has really raised a Series-A/B?
# Ask HN: Best way to start and master Hadoop?
# Ask HN: Books on how Email works and how to program services around it
# Ask HN: Do you have an HN realname and also a sock puppet account?
# Ask HN: Would Elon Musk Make a Better President Than Hillary?
# Ask HN: How would you handle an E.T. signal with a 95 year latency?
# Ask HN: What is the difference between a product and a solution?
# Ask HN: Any Product Hunt moderator here?
# Ask HN: Do you have a Oracle to PostgreSQL migration success story?
# Ask HN: How did you launch your product?
# Ask HN: Straight question  WTF happened to Apple's innovation?
# Ask HN: How do you measure residential ISP uptime?
# Ask HN: What is this job role worth?
# Ask HN: Bald men and depression
# Ask HN: Which security vulnerability feeds should I Monitor?
# Ask HN: Challenges in engineering on-boarding?
# Ask HN: Idea for a startup, as a one-man team what should I do next?
# Ask HN: How do I hire for jobs I'm not an expert in?
# Ask HN: Is pomodoro technique effective for programmers?
# Ask HN: Have you tried probabilistic/Bayesian programming?
# Ask HN: Want to connect with Startup School attendees before the event?
# Ask HN: Single-user task and project management recs?
# Ask HN: What are your startup ideas that you aren't pursuing?
# Ask HN: Best practices for supporting remote employees?
# Ask HN: How to perform external monitoring of single-page web apps?
# Ask HN: Who knows a founder of Teamreporterapp? I want to buy this project
# Ask HN: A public transport service that adapts your context
# Ask HN: Career solo developer. How do companies plan/build in real world?
# Ask HN: Where do you get your news from?
# Ask HN: How to prepare for a job change?
# Ask HN: What's the easiest way to write a bot to read articles and learn?
# Ask HN: Those 'employed' do you see no other resort?
# Ask HN: What to expect when a completely new coder
# Ask HN: Is anyone using splunk as graphite/statsd replacement?
# Ask HN: What do you think when you see a post is from Medium?
# Ask HN: Does Signal fail to be a decent WhatsApp alternative
# Ask HN: Should I leave my startup?
# Ask HN: Storing passports pics in the cloud, any technical advice?
# Ask HN: How long should a partnership wait before legally organizing?
# Ask HN: If I wanted to make a web browser, where would I start?
# Ask HN: Good source code search engines?
# Ask HN: Why is Google so bad at UI Design?
# Ask HN: Help with acqhire from EU by US company?
# Ask HN: Ultimate guide for configuring IKEv2 in pfSense to connect behind NAT?
# Ask HN: Thoughts on Facebook Building 8?
# Ask HN: Cryptochallenge like websites
# Ask HN: Are you bearish or bullish on Ether? Why?
# Ask HN: How much should I charge per hour as Developer?
# Ask HN: Should I let clients delete their data?
# Ask HN: Could you give up flying?
# Ask HN: Chatbot for rentals or App for rentals?
# Ask HN: Using Cloud Foundry in production?
# Ask HN: Real time one way replication on Linux?
# Ask HN: What kind of projects should I build for a front-end portfolio?
# Ask HN: Has anyone tried Google Duo yet?
# Ask HN: Why speakers are counting hands on every conference talk?
# Ask HN: Where Do You Live?
# Ask HN: Change C-corp name, or file for a DBA?
# Ask HN: Should i build an auto-parallelizer for C or for JAVA?
# Ask HN: How do you learn a new concept/programming language/ framework?
# Ask HN: Best practices for software development?
# Ask HN: Help Looking to find the x,y,z coordinates of a point in a room
# Ask HN: What to chose as a framework for MVP for expirienced developer
# Ask HN: Microservices testing best practises?
# Ask HN: What are your startup ideas that you aren't pursuing?
# Ask HN: Elm-like JavaScript framework?
# Ask HN: How to validate a SaaS product?
# Ask HN: How do you handle DDoS attacks?
# Ask HN: What's the best library for making cross-platform UIs?
# Ask HN: Business/initial-idea guy seeks technical founder; what's the process?
# Ask HN: I Wanted to Bootstrap a Business Not Write Volumes of Marketing Content
# Ask HN: Function as a service for Ruby?
# Ask HN: How to find remote software engineering job in India?
# Ask HN: Is it cool to ask website visitors help your charity?
# Ask HN: Is there space for a technology matchmaker?
# Ask HN: How do I prevent programs actively detecting they're running in a VM?
# Ask HN: What should I do with a broken laptop
# Ask HN: Starting machine learning? Books, videos and other resources
# Ask HN: What is your favorite book?
# Ask HN: Is gravity a renewable energy source
# Ask HN: I am doing $2M annually as a solopreneur and need your help
# Ask HN: How do I get feedback about my startup?
# Ask HN: Performance optimizations for Geospatial applications
# Ask HN: Why was my submission flagged?
# Ask HN: Accuracy of ip to geo location?
# Ask HN: Early signs that a company is failing?
# Ask HN: Are there any Indian female programmers on HN?
# ...
# Ask HN: Hacker houses in SF/Bay Area for 1 week?
# Ask HN: New Research Papers on Data Structures and Algorithms?
# Ask HN: What is the best way to monetize animated video series?
# Ask HN: Do you have stories about Luddite authority overreaction?
# Ask HN: What submission has the highest point score?
# Ask HN: What's your favorite ruby HTTP client?
# Ask HN: Is it normal that my iphone app has been in review for 45 days?
# Ask HN: Why is home contracting so horrendeous?
# Ask HN: Huge pages on Mac OS X
# Ask HN: Discontd UBNT AirRouter still best buy for sm home/office/OpenWRT bgnr?
# Ask HN: Anyone doing Transcendental Meditation?
# Ask HN: Start date is set, but I got another offer. What to do?
# Ask HN: How would you sell open source software?
# Ask HN: Do you deploy apps using deb/rpm packages?
# Ask HN: Do you feel guilty when you quit a job?
# Ask HN: Can this way we support publishers and readers, and also get rid of ads?
# Ask HN: How to find remote freelance work for a graphic designer?
# Ask HN: Will adblockers kill js widget products/startups?
# Ask HN: Zoho mail custom domain and alternatives
# Ask HN: Looking for suggestions on fairly basic IT Asset Management webapps
# Ask HN: What do you think of the movie Office Space?
# Ask HN: Which diplomas/certificates to make me able to get a TN visa?
# Ask HN: Could sites let their ad provider serve content to thwart ad blockers?
# Ask HN: I have an idea to fix the DNS change problem
# Ask HN: Revision tips for a struggling high school student?
# Ask HN: What do you use to transfer links and files?
# Ask HN: Is it necessary to know algo and ds to be a good programmer
# Ask HN: What makes Hacker News so special?
# Ask HN: Accessible lower environments?
# Ask HN: Can you name companies (5+ employees) with distributed/nomadic teams?
# Ask HN: What's the web link for?
# Ask HN: Platform to read HDMI, warp video and output HDMI
# Ask HN: Are blue-light blocking glasses effective?
# Ask HN: Pay to turn off ads SaaS
# Ask HN: I've applied at Toptal and failed the Codility tests
# Ask HN: Recommendations for blog posts about successful side projects?
# Ask HN: I found a problem in Google Groups
# Ask HN: Must-haves when it comes to optimising web applications performance?
# Ask HN: Did anyone tried Polymer?
# Ask HN: How can I keep focused?
# Ask HN: How do I ask for more money as an intern
# Ask HN: Who will win the ad-blocking fight, long term?
# Ask HN: How do I expedite Apple App Store review?
# Ask HN: What should I ask a startup CEO in an interview?
# Ask HN: What type of apps would you use on the new Apple TV?
# Ask HN: Financial startup asks for private info via email. Where do I complain?
# Ask HN: Production ready postgres ORM for Node.js?
# Ask HN: Why is Facebook Messenger  so unstable?
# Ask HN: Platform to meet people for learning
# Ask HN: Extension for Toggl that can take screenshots?
# Ask HN: The new past link on some submissions
# Ask HN: Why did the Amazon fire phone fail?
# Ask HN: How do automated native app services work?
# Ask HN: Corporate sponsor for school library app experiment?
# Ask HN: iOS 9 is out with its ad-blocker support. How do you feel about that?
# Ask HN: What are your favorite podcasts?
# Ask HN: Best books or videos to get better at sales?
# Ask HN: How to Find Open Source Projects to Contribute To
# Ask HN: Why is startupdeveloperjobs.com down?
# Ask HN: What development methodologies do you prefer and why?
# Ask HN: What am I doing wrong or where is the Fail?
# Ask HN: What do the smartest people do
# Ask HN: Have you taught informal classes/study groups at work?
# Ask HN: Standing seats  all day use OK?
# Ask HN: Does anyone know what happened to Reia?
# Ask HN: Source control with micro services
# Ask HN: How do you find a trustworthy technical co-founder?
# Ask HN: Which CSS/HTML frameworks should I consider for modern web development?
# Ask HN: What should I be doing with our business' cash?
# Ask HN: How did you land your first B2B customer?
# Ask HN: Anyone interested in a mastermind group?
# Ask HN: What would be the ideal Software Engineering curriculum?
# Ask HN: Anyone here changed carrer from programming to Oracle ERP?
# Ask HN: Better way to construct UIs than Interface Builder?
# Ask HN: Best resource to learn react and react native?
# Ask HN: Mobile, social, geo all saturated  what's next?
# Ask HN: Best resources to learn low-level programming?
# Ask HN: Link submission overload in HN
# Ask HN: How do I search source code of popular projects only?
# Ask HN: Could someone give a feedback about inspirebeats.com?
# Ask HN: How do I joint Y Combinator project?
# Ask HN: How can you use Stack Exchange without throwing up?
# Ask HN: Re:Invent ticket wanted
# Ask HN: Big Companies built by founders that had already failed
# Ask HN: Is webgl a good idea that will never quite make it?
# Ask HN: 60-70% of our Stripe charges are failing. Help
# Ask HN: What are you reading?
# Ask HN: How does email tracking work?
# Ask HN: Buy re:Invent ticket
# Ask HN: How does Intercom and other web apps auto populate user images?
# Ask HN: What happened to older submissions on HN (only about 500 are visible)?
# Ask HN: Why do keyboards still have the CAPS LOCK key?
# Ask HN: Affordable Business Plan Writing Service(s)?
# Ask HN: What technology/products do you use for home automation?
# Ask HN: When Topics Affect Me but I Am Not Aware and Not Interested
# Ask HN: Why don't publishers serve ads from their domains to thwart ad-blockers?
# Ask HN: Is your company not using React.js due to PATENT file?
# Ask HN: What type of apps would you use on the new Apple TV?
# Ask HN: I want to email ads to content outlets like NYT. How?
# Ask HN: Best Mac OS X Password Manager
# Ask HN: I own nextlesson.com what should I make with it?
# Ask HN: Why were names of other passengers appearing in my flight details?
# Ask HN: Can someone provide a apk for the react native Facebook samples?
# Ask HN: How do you manage your contacts?
# Ask HN: Anyone in Tokyo want to hack?
# Ask HN: Is there any reading material for Mach-O?
# Ask HN: Mobile app to ask me to log a data point daily
# Ask HN: What is the license of comments here?
# Ask HN: Anyone in NYC area want to hack?
# Ask HN: Which NLP API services do you use?
# Ask HN: Is anyone here a Network Operations Center(NOC) Engineer?
# Ask HN: Niche Markets Worth Targeting with a Job Board
# Ask HN: Why is Apple still releasing 16 GB phones?
# Ask HN: What do you use for spell checking?
# Ask HN: I own mrrobot.io Should I build something on it or sell it?
# Ask HN: What is the lifespan of a Raspberry Pi Model A+?
# Ask HN: What are you working on right now?
# Ask HN: Modern Advances in Systems Software?
# Ask HN: Do you use a scrum master in your team?
# Ask HN: Is it common knowledge that Yahoo benefits from (relies on?) adware?
# Ask HN: Facebook clickjacking  is it detectable?
# Ask HN: Can you scrape e-mail and name from Gmail Inbox?
# Ask HN: New G+ Logo?
# Ask HN: The new peek and pop feature in IPhone 6S
# Ask HN: How do software consultants deal with maintenance?
# Ask HN: Do you need a big network to be successful?
# Ask HN: What should be minimal stack to be called Full Stack Developer
# Ask HN: What cloud companies offer free compute resources to startups?
# Ask HN: What is your way to get inspiration for new projects?
# Ask HN: How would you introduce kids in rural India to computers?
# Ask HN: How do certain companies achieve such high visa acceptance?
# Ask HN: How can I help others?
# Ask HN: Understanding of networks is necessary for Web Developer?
# Ask HN: Great nontech book that you read recently?
# Ask HN: How can I send an open letter to HP?
# Ask HN: How to monetise helmetrex.com?
# Ask HN: Any tips on finding relevant Shopify/Magento store owners?
# Ask HN: Can a software ever be 100% bug free?
# Ask HN: Any Ubuntu phone OS users here? How do you like it?
# Ask HN: My school needs a data storage solution
# Ask HN: JSON Web Token (JWT) Implementation Experiences
# Ask HN: Do you value your company based on a multiple of EBITA or gross revenue?
# Ask HN: Any software to parse a PDF word by word? (maybe into SVG)
# Ask HN: What research areas would you consider if you were to start a CS PhD?
# Ask HN: Where do you keep your medical data?
# Ask HN: I have a crazy idea. How do I approach VCs?
# Ask HN: Is there an API to get what is trending at this time?
# Ask HN: Is YouTube back to using flash?
# Ask HN: Late cofounder
# Ask HN: Testing free-speech app intended for activists. Anyone interested?
# Ask HN: Is VMware Doomed?
# Ask HN: Do you expect Rails to last in front of the JavaScript revolution?
# Ask HN: Have you converted to software engineering from another profession?
# Ask HN: I will work for you a year for food  if you sponsor my visa
# Ask HN: Fypayme as a service?
# Ask HN: Have there been any major developments in Law Tech in the last year?
# Ask HN: What challenges do companies have adopting and using open source?
# Ask HN: Starting a porn startup
# Ask HN: What are the best Product Management internships?
# Ask HN: Are there any statistics on the Bay Area talent crunch?
# Ask HN: Should I take an idea to the chief executive?
# Ask HN: Books that altered your view of reality
# Ask HN: What should you ask for in an employment contract when being acquihired?
# Ask HN: How do I organize an HN Meetup in my city?
# Ask HN: What Can You Do with a BA in English?
# Ask HN: Is work worth leaving College for?
# Ask HN: Been getting calls from Windows technical department
# Ask HN: What will be the next wow product like the first iPhone?
# Ask HN: Programming for non-programmers?
# Ask HN: Any recent alternative to http the definitive guide
# Ask HN: Dollar Shave Club for Printer Ink
# Ask HN: Does anybody use Grails?
# Ask HN: Creating a new web app  what's your chosen stack, tools and services?
# Ask HN: Best way to sell unused domains without paying fees?
# Ask HN: New Product WorkIt research, have time for 3 question survey
# Ask HN: Why do companies care about adblock?
# Ask HN: How do I clear my mind and regain focus?
# Ask HN: Time Warner Cable doubled my internet speed. Why dont pages load faster?
# Ask HN: You know any service to create style guides (like frontify)?
# Ask HN: Signing full time job offer, possible conflict of interest?
# Ask HN: I'm being stiffed by a client. What are my options?
# Ask HN: How often do you really reuse ?your code?
# Ask HN: Where do Rubyists host their application?
# Ask HN: How important is original learning content for a Dev Bootcamp?
# Ask HN: How developers in enterprises and startups can spend money?
# Ask HN: What is the worst you poured over your keyboard?
# Ask HN: Is RSS still worth the time?
# Ask HN: Does not new Google logo seem a bit too naive?
# Ask HN: How to become a independent researcher?
# Ask HN: How does a TV show recording get to the networks?
# Ask HN: What's your 1-man startup?
# Ask HN: Can a web agency operate the same way a law firm does?
# Ask HN: Any problems with the new TLDs?
# Ask HN: Who are your favorite SaaS thought leadership bloggers?
# Ask HN: What are the biggest API development issues that you face?
# Ask HN: What is your compensation and location?
# Ask HN: Existing convertible note advantage or obstacle for YC?
# Ask HN: What startup podcasts do you listen to?
# Ask HN: Should I let an agency promote our incredible orca video?
# Ask HN: Retro show HN?
# Ask HN: How to stop procrastination?
# Ask HN: Where to move within US?
# Ask HN: Accurately tracking uniques on a high traffic site
# Ask HN: Should I quit my job (or work part-time) to join an Uber for X startup
# Ask HN: Best HN hiring search app?
# Ask HN: Which browser is best with annotation?
# Ask HN: API: Where Should I Launch NLP API
# Ask HN: Best way to become a front end developer?
# Ask HN: Performance Reviews for SMEs?
# Ask HN: What is science?
# Ask HN: Build a product with no revenue?
# Ask HN: Would you pay to use a good GIF encoder designed for iOS?
# Ask HN: What's in the Firefox future?
# Ask HN: What Is Apple's Live Photo Technology?
# Ask HN: Google Image Charts alternative
# Ask HN: Does anybody want to develop for Apple products anymore?
# Ask HN: Safe to store pgp encrypted keys publicly on GitHub?
# Ask HN: Will Apple iPad pro wipe out Microsoft surface?
# Ask HN: (2nd try):   Possible solution for founders' going full time problem?
# Ask HN: Should I join a Startup or keep working on my own (for now)?
# Ask HN: How do you feel about ad blockers?
# Ask HN: Startup owners/employees, would you use a service like this?
# Ask HN: Android Material design pattern guide?
# Ask HN: Is there any list which keeps track of companies that have shut down?
# Ask HN: Who do you use for hosting?
# Ask HN: How to mitigate the risks of open sourcing a project?
# Ask HN: Do you think we'll see any Twitter/Facebook real-competitor?
# Ask HN: Where's All the Entrepreneurship / Bootstrapping Content?
# Ask HN: What did you do on your last day at office?
# Ask HN: Best European, Asian, and Indian Developer Conferences
# Ask HN: Best European, Asian, and Indian Developer Conferences
# Ask HN: Startups  Make Money vs. Change the World
# Ask HN: I am underpaid and overworked  how much equity do I deserve?
# Ask HN: How to make use of the maximum of a tech conference?
# Ask HN: Psychologists in modern companies. Do many have them and if not, why?
# Ask HN: CTM gave CS the kernel language. Is there a kernel database?
# Ask HN: How to get a job in the oil industry in North Dakota?
# Ask HN: Would a website that shows the tech stacks of nearby companies useful?
# Ask HN: Should we have a Who is hiring? for non-profit volunteer positions?
# Ask HN: How to explain to cost of technical labor to a non-technical investor
# Ask HN: Want to start a small hardware company.  What are some good resources?
# Ask HN: How to promote and open source IoT Platform?
# Ask HN: Which email service to use for Custom Domain?
# Ask HN: What apps would help individuals in high need or catastrophic events?
# Ask HN: Whats a local cool startup in your area still not in other countries
# Ask HN: How are you using Twitter?
# Ask HN: What's the use of part of speech tagging
# Ask HN: What's the best non-tech book you ever read?
# Ask HN: Resources for learning ASP.NET?
# Ask HN: What should concern a guest poster?
# Ask HN: Hacker Way to find sales lead
# Ask HN: How to get in touch with a small country DNS registrar?
# Ask HN: Where and how do you look for jobs?
# Ask HN: Founders' going full time problem  possible solution?
# Ask HN: Cover Letters for Tech Internships
# Ask HN: Partial Aorta Artery Repair
# Ask HN: Unhappy at work, what should I do?
# Ask HN: Demand for software modeling bootcamp?
# Ask HN: Are freemium microservices a thing?
# Ask HN: If you are learning Chinese
# Ask HN: Is it still ok to build an app with a twit/tweet prefixed domain?
# Ask HN: Thoughts on an alternative to Public Key Pinning (HPKP)?
# Ask HN: What are the latest and greatest books on your favorite language?
# Ask HN: What is the best recommended domain name registration site?
# Ask HN: Can I use Patreon to sustain a blog
# Ask HN: How to account for annual prepayments in SaaS startups MRR?
# Ask HN: What are some must read newsletters for Developers?
# Ask HN: Should I send mail to remind myself to interviewer
# Ask HN: Freelancers, what tools do you use
# Ask HN: What is the SICP for aerospace and/or ships?
# Ask HN: Exporting AWS Lambda?
# Ask HN: How do you become VP of Engineering?
# Ask HN: Am I the only one lost interest applying YC?
# Ask HN: Founders of large tech companies that work from home
# Ask HN: What license does Hacker News use?
# Ask HN: Developing/selling Wordpress plugins
# Ask HN: Are you still using apple music?
# Ask HN: How do you people with food allergies deal with  eating outside?
# Ask HN: What to do on a 14 hour flight?
# Ask HN: How to prepare for Tech Interviews?
# Ask HN: What Should I Including on My Company Report Card?
# Ask HN: How to keep young developers
# Ask HN: Discrete Mathematics Help
# Ask HN: How have you changed your password to make it easier to type on mobile?
# Ask HN: Is coursera specialization in product management worth doing?
# Ask HN: Any meteor devs out there who could spend 5 min helping an idiot?
# Ask HN: Any recommendations for books about rationality / scientific thinking?
# Ask HN: Where do you look for work if you need experience?
# Ask HN: What is/are your favorite quote(s)?

# %% [markdown]
# We can see that there are many posts with **Ask HN**. To make sure we have all variations of the way "Ask HN" can be capitalized we can convert all title strings to lowercase. To prepare a separate list for the two different posts we can create two lists to store the data.

# %%
ask_posts = []
show_posts = []
other_posts = []

for row in hn:
    title = row[1]
    title = title.lower()
    if title.startswith('ask hn'):
        ask_posts.append(row)
    elif title.startswith('show hn'):
        show_posts.append(row)
    else:
        other_posts.append(row)

# %% [markdown]
# Now we can check the length of each list to see how many of each post there are.

# %%
print(len(ask_posts))
print(len(show_posts))
print(len(other_posts))
# Out:
# 9139
# 10158
# 273822

# %% [markdown]
# There are many more show posts in the data set. Let's take a closer look at each one.

# %%
print(ask_posts[:5])
print(show_posts[:5])
# Out:
# [['12578908', 'Ask HN: What TLD do you use for local development?', '', '4', '7', 'Sevrene', '9/26/2016 2:53'], ['12578522', 'Ask HN: How do you pass on your work when you die?', '', '6', '3', 'PascLeRasc', '9/26/2016 1:17'], ['12577908', 'Ask HN: How a DNS problem can be limited to a geographic region?', '', '1', '0', 'kuon', '9/25/2016 22:57'], ['12577870', 'Ask HN: Why join a fund when you can be an angel?', '', '1', '3', 'anthony_james', '9/25/2016 22:48'], ['12577647', 'Ask HN: Someone uses stock trading as passive income?', '', '5', '2', '00taffe', '9/25/2016 21:50']]
# [['12578335', 'Show HN: Finding puns computationally', 'http://puns.samueltaylor.org/', '2', '0', 'saamm', '9/26/2016 0:36'], ['12578182', 'Show HN: A simple library for complicated animations', 'https://christinecha.github.io/choreographer-js/', '1', '0', 'christinecha', '9/26/2016 0:01'], ['12578098', 'Show HN: WebGL visualization of DNA sequences', 'http://grondilu.github.io/dna.html', '1', '0', 'grondilu', '9/25/2016 23:44'], ['12577991', 'Show HN: Pomodoro-centric, heirarchical project management with ES6 modules', 'https://github.com/jakebian/zeal', '2', '0', 'dbranes', '9/25/2016 23:17'], ['12577142', 'Show HN: Jumble  Essays on the go #PaulInYourPocket', 'https://itunes.apple.com/us/app/jumble-find-startup-essay/id1150939197?ls=1&mt=8', '1', '1', 'ryderj', '9/25/2016 20:06']]

# %% [markdown]
# ## Analyzing comments of posts
#
# ---

# %% [markdown]
# Now that we have separate lists for ask posts and show posts, we are tasked with finding the number of comments for ask posts.

# %%
total_ask_comments = 0

for post in ask_posts:
    total_ask_comments += int(post[4])
    
avg_ask_comments = total_ask_comments / len(ask_posts)
   
print('The total number of comments belonging to ask posts is:', total_ask_comments)    
print('The total number of "Ask HN" posts is:', len(ask_posts))
print('The average number of comments for ask posts is:', avg_ask_comments)
# Out:
# The total number of comments belonging to ask posts is: 94986
# The total number of "Ask HN" posts is: 9139
# The average number of comments for ask posts is: 10.393478498741656

# %%
total_show_comments = 0

for row in show_posts:
    total_show_comments += int(post[4])

avg_show_comments = total_show_comments / len(show_posts)

print('The total number of comments belonging to show posts is:', total_show_comments)    
print('The total number of "Show HN" posts is:', len(show_posts))
print('The average number of comments for show posts is:', avg_show_comments)
# Out:
# The total number of comments belonging to show posts is: 203160
# The total number of "Show HN" posts is: 10158
# The average number of comments for show posts is: 20.0

# %% [markdown]
# We can see that all though there are more **Show HN** posts, the number of comments is significantly lower. This is somewhat expected due to the nature of these posts. It seems commenters are engaging more on posts where they are asked a specific question and engaging loss on posts that simply show something that a member wants to share.

# %% [markdown]
# ## Time data of Ask HN Posts
#
# ---

# %% [markdown]
# Now that we know ask posts attract more comments, let's determine if time of day affects the number of comments received. We will do this by calculating the number of ask posts created and the number of comments received for each hour of the day. We will then calculate the average number of comments for each hour.

# %%
import datetime as dt

result_list = []

for post in ask_posts:
    result_list.append(
        [post[6], int(post[4])])
    
print(result_list[:5])
# Out:
# [['9/26/2016 2:53', 7], ['9/26/2016 1:17', 3], ['9/25/2016 22:57', 0], ['9/25/2016 22:48', 3], ['9/25/2016 21:50', 2]]

# %% [markdown]
# ## Finding the Amount of Comments by Hour for Ask Posts
#
# ---

# %%
counts_by_hour = {}
comments_by_hour = {}
date_format = '%m/%d/%Y %H:%M'

for row in result_list:
    date = row[0]
    comment = row[1]
    time = dt.datetime.strptime(date, date_format).strftime("%H")
    if time not in counts_by_hour:
        counts_by_hour[time] = 1
        comments_by_hour[time] = comment
    else:
        counts_by_hour[time] += 1
        comments_by_hour[time] += comment
        
comments_by_hour
# Out:
# {'02': 2996,
#  '01': 2089,
#  '22': 3372,
#  '21': 4500,
#  '19': 3954,
#  '17': 5547,
#  '15': 18525,
#  '14': 4972,
#  '13': 7245,
#  '11': 2797,
#  '10': 3013,
#  '09': 1477,
#  '07': 1585,
#  '03': 2154,
#  '23': 2297,
#  '20': 4462,
#  '16': 4466,
#  '08': 2362,
#  '00': 2277,
#  '18': 4877,
#  '12': 4234,
#  '04': 2360,
#  '06': 1587,
#  '05': 1838}

# %% [markdown]
# ## Calculating the Average Number of Momments by Hour
#
# ---

# %%
avg_by_hour = []

for hr in comments_by_hour:
    avg_by_hour.append([hr, comments_by_hour[hr] / counts_by_hour[hr]])
    
avg_by_hour
# Out:
# [['02', 11.137546468401487],
#  ['01', 7.407801418439717],
#  ['22', 8.804177545691905],
#  ['21', 8.687258687258687],
#  ['19', 7.163043478260869],
#  ['17', 9.449744463373083],
#  ['15', 28.676470588235293],
#  ['14', 9.692007797270955],
#  ['13', 16.31756756756757],
#  ['11', 8.96474358974359],
#  ['10', 10.684397163120567],
#  ['09', 6.653153153153153],
#  ['07', 7.013274336283186],
#  ['03', 7.948339483394834],
#  ['23', 6.696793002915452],
#  ['20', 8.749019607843136],
#  ['16', 7.713298791018998],
#  ['08', 9.190661478599221],
#  ['00', 7.5647840531561465],
#  ['18', 7.94299674267101],
#  ['12', 12.380116959064328],
#  ['04', 9.7119341563786],
#  ['06', 6.782051282051282],
#  ['05', 8.794258373205741]]

# %% [markdown]
# ## Swapping and Sorting Values in a List
#
# ---

# %%
swap_avg_by_hour = []

for row in avg_by_hour:
    swap_avg_by_hour.append([row[1], row[0]])
    
swap_avg_by_hour
# Out:
# [[11.137546468401487, '02'],
#  [7.407801418439717, '01'],
#  [8.804177545691905, '22'],
#  [8.687258687258687, '21'],
#  [7.163043478260869, '19'],
#  [9.449744463373083, '17'],
#  [28.676470588235293, '15'],
#  [9.692007797270955, '14'],
#  [16.31756756756757, '13'],
#  [8.96474358974359, '11'],
#  [10.684397163120567, '10'],
#  [6.653153153153153, '09'],
#  [7.013274336283186, '07'],
#  [7.948339483394834, '03'],
#  [6.696793002915452, '23'],
#  [8.749019607843136, '20'],
#  [7.713298791018998, '16'],
#  [9.190661478599221, '08'],
#  [7.5647840531561465, '00'],
#  [7.94299674267101, '18'],
#  [12.380116959064328, '12'],
#  [9.7119341563786, '04'],
#  [6.782051282051282, '06'],
#  [8.794258373205741, '05']]

# %%
sorted_swap = sorted(swap_avg_by_hour, reverse=True)

# %%
print("The 5 Busiest Hours for 'Ask HN' Comments")
for avg, hr in sorted_swap[:5]:
    print(
        "{}: There are {:.2f} average comments per post".format(
            dt.datetime.strptime(hr, "%H").strftime("%H:%M"),avg
        )
    )
# Out:
# The 5 Busiest Hours for 'Ask HN' Comments
# 15:00: There are 28.68 average comments per post
# 13:00: There are 16.32 average comments per post
# 12:00: There are 12.38 average comments per post
# 02:00: There are 11.14 average comments per post
# 10:00: There are 10.68 average comments per post

# %% [markdown]
# ## For Further Analysis:
#
# ---

# %% [markdown]
# Here are some next steps for you to consider:
#
# * Determine if show or ask posts receive more points on average.
# * Determine if posts created at a certain time are more likely to receive more points.
# * Compare your results to the average number of comments and points other posts receive.
# * Use Dataquest's data science project style guide to format your project.
